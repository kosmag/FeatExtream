# %%
import math
import pandas as pd
import numpy as np
from datetime import datetime

# %%
pd.set_option('display.max_columns', None)

# %%
path = r'C:\Users\kosma\Desktop\MAGISTER\\DataExpo2009\csv\2007.csv'

# %%
frame = pd.read_csv(path, index_col=None, sep = ',')

# %%
frame.count()
# Out:
# Year                 7453215
# Month                7453215
# DayofMonth           7453215
# DayOfWeek            7453215
# DepTime              7292467
# CRSDepTime           7453215
# ArrTime              7275288
# CRSArrTime           7453215
# UniqueCarrier        7453215
# FlightNum            7453215
# TailNum              7453193
# ActualElapsedTime    7275288
# CRSElapsedTime       7452221
# AirTime              7275288
# ArrDelay             7275288
# DepDelay             7292467
# Origin               7453215
# Dest                 7453215
# Distance             7453215
# TaxiIn               7453215
# TaxiOut              7453215
# Cancelled            7453215
# CancellationCode      160749
# Diverted             7453215
# CarrierDelay         7453215
# WeatherDelay         7453215
# NASDelay             7453215
# SecurityDelay        7453215
# LateAircraftDelay    7453215
# dtype: int64

# %%
frame.drop_duplicates().count()
# Out:
# Year                 7453188
# Month                7453188
# DayofMonth           7453188
# DayOfWeek            7453188
# DepTime              7292440
# CRSDepTime           7453188
# ArrTime              7275261
# CRSArrTime           7453188
# UniqueCarrier        7453188
# FlightNum            7453188
# TailNum              7453166
# ActualElapsedTime    7275261
# CRSElapsedTime       7452194
# AirTime              7275261
# ArrDelay             7275261
# DepDelay             7292440
# Origin               7453188
# Dest                 7453188
# Distance             7453188
# TaxiIn               7453188
# TaxiOut              7453188
# Cancelled            7453188
# CancellationCode      160749
# Diverted             7453188
# CarrierDelay         7453188
# WeatherDelay         7453188
# NASDelay             7453188
# SecurityDelay        7453188
# LateAircraftDelay    7453188
# dtype: int64

# %%
frame
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2007      1           1          1   1232.0        1225   1341.0
# 1        2007      1           1          1   1918.0        1905   2043.0
# 2        2007      1           1          1   2206.0        2130   2334.0
# 3        2007      1           1          1   1230.0        1200   1356.0
# 4        2007      1           1          1    831.0         830    957.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7453210  2007     12          15          6   1558.0        1605   1749.0
# 7453211  2007     12          15          6   1902.0        1851   2110.0
# 7453212  2007     12          15          6   1024.0        1025   1750.0
# 7453213  2007     12          15          6   1353.0        1315   1658.0
# 7453214  2007     12          15          6   1824.0        1800   2001.0
#
#          CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# ...

# %%
set(frame['DepTime'])
# Out:
# {nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  11.0,
#  17.0,
#  10.0,
#  19.0,
#  16.0,
#  18.0,
#  22.0,
#  20.0,
#  3.0,
#  23.0,
#  5.0,
#  24.0,
#  28.0,
#  25.0,
#  30.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  33.0,
#  nan,
#  32.0,
#  36.0,
#  43.0,
#  44.0,
#  45.0,
#  46.0,
#  47.0,
#  8.0,
#  40.0,
#  50.0,
#  48.0,
#  52.0,
#  53.0,
#  9.0,
#  55.0,
#  2.0,
#  57.0,
#  51.0,
#  54.0,
#  56.0,
#  12.0,
#  59.0,
#  58.0,
#  nan,
#  13.0,
#  14.0,
#  15.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  100.0,
#  101.0,
#  102.0,
#  103.0,
#  104.0,
#  105.0,
#  106.0,
#  107.0,
#  108.0,
#  21.0,
#  110.0,
#  111.0,
#  112.0,
#  113.0,
#  114.0,
#  115.0,
#  116.0,
#  117.0,
#  118.0,
#  119.0,
#  120.0,
#  121.0,
#  122.0,
#  123.0,
#  124.0,
#  125.0,
#  126.0,
#  127.0,
#  128.0,
#  129.0,
#  130.0,
#  131.0,
#  132.0,
#  133.0,
# ...

# %%
path = r'C:\Users\kosma\Desktop\2007_14col.data'

# %%
frame = pd.read_csv(path, index_col=None, sep = ',')

# %%
frame
# Out:
#          2007   1  1.1  1.2    10  738  NW   336  270  LAX  DTW  1979  0  -4
# 0        2007   1    1    1    15  633  US  1198  259  PHX  PHL  2075  0  25
# 1        2007   1    1    1    25  510  AA  2402  162  LAX  DFW  1235  0  36
# 2        2007   1    1    1    30  535  AA   872  187  SMF  DFW  1431  0  -3
# 3        2007   1    1    1    30  545  AA   530  191  SFO  DFW  1464  0  42
# 4        2007   1    1    1    30  556  CO  1743  202  SFO  IAH  1635  0 -13
# ...       ...  ..  ...  ...   ...  ...  ..   ...  ...  ...  ...   ... ..  ..
# 7275282  2007  12   31    1  2359  616  DL  1664  256  SLC  JFK  1989  0   4
# 7275283  2007  12   31    1  2359  619  B6   106  242  TUS  JFK  2136  0   2
# 7275284  2007  12   31    1  2359  729  US  1734  202  LAS  ATL  1747  0 -55
# 7275285  2007  12   31    1  2359  756  US   219  256  LAS  EWR  2227  0 -31
# 7275286  2007  12   31    1  2359  800  B6    86  286  SEA  JFK  2421  0 -15
#
# [7275287 rows x 14 columns]
