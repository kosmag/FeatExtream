# %%
import subprocess
import pathlib
import random
import numpy as np
import pandas as pd

# %%
def random_search(f, hyperparameters, tries, set_seed=10):
    #Random search algorithm 
    random.seed(set_seed)
    best_result = None
    best_params = None
    for i in range(0, tries):
        random_params = choose_random_hyperparameters(hyperparameters)
        result = f(random_params)
        if  best_result is None or result > best_result:
            best_params = random_params
            best_result = result
    return best_params

def choose_random_hyperparameters(hyperparameters):
    random_params = []
    for hyperparam in hyperparameters:
        random_params.append(random.choice(hyperparam))
    return random_params

# %%
def greedy_search(f, hyperparameters, starting_parameters, tries_per_param, set_seed=10):
    #Greedy algorithm - optimize one hyperparameter at a time
    random.seed(set_seed)
    current_parameters = starting_parameters
    param_index = 0
    best_result = f(starting_parameters)
    for hyperparam in hyperparameters:
        if tries_per_param >= len(hyperparam):
            values = hyperparam
        else:
            values = random.sample(hyperparam, k=tries_per_param)
        for value in values:
            tested_parameters = current_parameters[:param_index] + [value] + current_parameters[param_index + 1:]
            result = f(tested_parameters)
            if result > best_result:
                current_parameters = tested_parameters
                best_result = result
        param_index += 1
    return current_parameters

# %%
test_parameters = [[1,2,3], [10,20,30], [100,200,300]]
def test_f(numbers):
    print(numbers)
    return sum(numbers)
starting_parameters = [2,30,100]

# %%
random_search(test_f, test_parameters, 5)
# Out:
# [3, 10, 200]
# [2, 30, 100]
# [1, 20, 200]
# [2, 30, 100]
# [1, 30, 200]
# [1, 30, 200]

# %%
greedy_search(test_f, test_parameters, starting_parameters, 2)
# Out:
# [2, 30, 100]
# [3, 30, 100]
# [1, 30, 100]
# [3, 20, 100]
# [3, 30, 100]
# [3, 30, 300]
# [3, 30, 100]
# [3, 30, 300]

# %%
datasets = {
    'airlines': (r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff', 50000, False, True, True, [-1,9,10], [''], ['-1']),
    'wisdm': (r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff',5000, True, True, True, ['-1'], [''], ['-1']),
    'electricity': (r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff',45000, True, True, True, [-1,1], ['0,2'], ['-1']),
    'vavel_sup_slim': (r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff',50000, False, True, True, [-1,13,14], ['0,5,7,9'], ['-1', '4,8', '4,8,12', '1,2,3,4,6,8,11,12']),
    'vavel_sup': (r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff',50000, False, True, True),
    'vavel':  (r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_90500.arff',50000, False, False, True, [-1,0,1,37,40], ['2,8,17,18,23'], ['-1','6,22','6,22,29','3,4,5,6,16,22,26,29']),
    'rbf':  ('generators.RandomRBFGenerator',50000, True, True, False, ['-1'], [''], ['-1']),
    'hyperplane':  ('generators.HyperplaneGenerator',50000, True, True, False, ['-1'], [''], ['-1']),
    'led':  ('generators.LEDGenerator',50000, True, True, False, ['-1'], [''], ['-1']),

}

def get_args(dataset):
    return {
        'name': dataset[0],
        'size': dataset[1],
        'classification': dataset[2],
        'supervised': dataset[3],
        'filebased': dataset[4],
        'partition_ids': dataset[5],
        'time_ids': dataset[6],
        'buffer_ids': dataset[7],

    }

# %%
buffer_sizes = sorted(list({int(i) for i in np.logspace(0, 2, num=12)}))
cluster_num = sorted(list({int(i) for i in np.logspace(0, 1.4, num=12)}))
extractor = ['cluster','featureExtraction', 'cep']
cluster_types = ['clustree', 'clustream']
buffer_types = ['random', 'relevance']
rs = list(np.linspace(0, 1, num=21)[1:])

reg_buffer_learners = [
    'rules.functions.TargetMean',
    'rules.functions.FadingTargetMean',
    'functions.AdaGrad',
    'meta.AdaptiveRandomForestRegressor -s 10',
    'meta.AdaptiveRandomForestRegressor -s 10 -m 80',
    'rules.AMRulesRegressor',
    'trees.ARFFIMTDD',

]

clf_buffer_learners = [
    'functions.MajorityClass',
    'functions.NoChange',
    'lazy.SAMkNN',
    'bayes.NaiveBayes',
    'meta.AdaptiveRandomForest -s 10',
    'meta.AdaptiveRandomForest -s 10 -m 80',
    'trees.HoeffdingAdaptiveTree',
    'meta.OzaBagAdwin',
]

class ExperimentRunner:
    def __init__(self, dataset):
        self.test_quotient = 1
        self.dataset = dataset
        self.exp_args = get_args(datasets[dataset])
        self.task = 'EvaluatePrequential' if self.exp_args['classification'] else 'EvaluatePrequentialRegression' 
        self.learner = 'BufferLearner'
        self.buffer_learners = clf_buffer_learners if self.exp_args['classification'] else reg_buffer_learners

        self.relevance_learner = '(functions.AdaGrad)'
        self.stream = f'(ArffFileStream -f {self.exp_args["name"]})' if self.exp_args['filebased'] else self.exp_args['name']

        self.sample_freq = 1000 / self.test_quotient
        self.index = 0
        self.outs = []
        self.ran_params = []
    
    def generate_command(self, extractor, buffer_learner, n, cluster_num,  partition_id, time_ids, buffer_ids, cluster_type, buffer_type, r, target_dir = ''):
        pathlib.Path(f'runs/tuning/{target_dir}/{self.dataset}/{extractor}').mkdir(parents=True, exist_ok=True)

        target_file = f'runs/tuning/{target_dir}/{self.dataset}/{extractor}/{buffer_learner.replace(".","").replace(" ","")}_{n}_{cluster_num}_{partition_id}_{time_ids}_{buffer_ids}_{cluster_type}_{buffer_type}_{int(r*100)}.csv'
        start_cmd = f'{self.task} -l ({self.learner} -l ({buffer_learner}) -n {n} -m {self.relevance_learner}'
        end_cmd = f') -s {self.stream} -i {int(self.exp_args["size"] / self.test_quotient)} -f {int(self.sample_freq)} -d {target_file}'
        cmd = f'{start_cmd} -c {extractor} -r {r} -b {buffer_type} -p {partition_id} {"" if time_ids == "" else f"-t {time_ids}"} -y {buffer_ids} -q {cluster_type} -x {cluster_num}{end_cmd}'
        cmd = cmd.replace("\\","/")
        return (cmd, target_file)
    
    def run_command(self, cmd, file_suffix):
        file_contents = f'@echo off\n\
        \n\
        set BASEDIR=%~dp0\..\n\
        set MEMORY=6g\n\
        \n\
        java -Xmx%MEMORY% -cp "%BASEDIR%/lib/*" -javaagent:"%BASEDIR%/lib/sizeofag-1.0.4.jar" ^\n\
        moa.DoTask ^\n\
        "{cmd} "'
        filename = r'..\moa-release-2020.07.1\bin\moa_test_run_' + file_suffix + '.bat'
        with open(filename, 'w') as file:
            file.write(file_contents)
        out = subprocess.Popen(filename)
        return out

    def run_and_get_value(self, params):
        if str(params) in self.ran_params:
            print("Params already ran - " + str(params))
            return float('-inf')
        self.ran_params.append(str(params))
        print(params)
        self.index += 1
        max_together = 1
        cmd, target_file = self.generate_command(params[0], params[1], params[2], params[3], params[4], 
                               params[5], params[6], params[7], params[8], params[9], target_dir = '20210831_test')
        print(f"Running cmd = {cmd}")
        out = self.run_command(cmd,f'{self.dataset}{self.index}')
        self.outs.append(out)

        if len(self.outs) >= max_together:
            self.outs[len(self.outs) - max_together].communicate()
        
        result_df = pd.read_csv(target_file, sep = ',')
        col_name = 'classifications correct (percent)' if self.exp_args['classification'] else 'mean absolute error'
        result = np.mean(result_df[col_name])
        print (f"Ran cmd with result {result}")
        run_result_file = target_file.rsplit( "/", 1 )[0] + "/_run_result.csv"
        with open(run_result_file, 'a') as file:
            stdev =  np.std(result_df[col_name])
            to_write = ",".join([str(p) for p in params]) + "," + "{:.2f}".format(stdev) + "," + "{:.2f}".format(result) + "\n"
            print("Writing " + to_write)
            file.write(to_write)
        return result if self.exp_args['classification']  else -result
            
    def run(self):       
        hyperparams_base = dict()
        for ex in extractor:
            hyperparams_base[ex] = [
                [ex],
                self.buffer_learners, 
                buffer_sizes, 
                cluster_num, 
                self.exp_args['partition_ids'], 
                self.exp_args['time_ids'], 
                self.exp_args['buffer_ids'],
                cluster_types,
                buffer_types,
                rs
            ]
            initial_params = random_search(self.run_and_get_value, hyperparams_base[ex], 10)
            best_params = greedy_search(self.run_and_get_value, hyperparams_base[ex], initial_params, 5)
            print(f"Best params for {ex}: "  + str(best_params))
    
    def run_standard_learners(self, target_dir):
        pathlib.Path(f'runs/tuning/{target_dir}/{self.dataset}/standard').mkdir(parents=True, exist_ok=True)
        target_path = [f'runs/tuning/{target_dir}/{self.dataset}/standard/{l.replace(" ","")}.csv' for l in self.buffer_learners]
        cmds = [f'{self.task} -l ({l}) -s {self.stream} -i {int(self.exp_args["size"] / self.test_quotient)} -f {int(self.sample_freq)} -d runs/tuning/{target_dir}/{self.dataset}/standard/{l.replace(" ","")}.csv' for l in self.buffer_learners]
        target_files = [f'runs/tuning/{target_dir}/{self.dataset}/standard/{l.replace(" ","")}.csv' for l in self.buffer_learners]
        max_together = 1
        for cmd, target_file, learner in zip(cmds,target_files, self.buffer_learners):
            self.index += 1
            print(f"Running cmd = {cmd}")
            out = self.run_command(cmd,f'{self.dataset}{self.index}')
            self.outs.append(out)

            if len(self.outs) >= max_together:
                self.outs[len(self.outs) - max_together].communicate()
            
            result_df = pd.read_csv(target_file, sep = ',')
            col_name = 'classifications correct (percent)' if self.exp_args['classification'] else 'mean absolute error'
            result = np.mean(result_df[col_name])
            rmse = np.mean(result_df['root mean squared error']) if not self.exp_args['classification'] else 0
            print (f"Ran cmd with result {result}")
            run_result_file = target_file.rsplit( "/", 1 )[0] + "/_run_result.csv"
            with open(run_result_file, 'a') as file:
                stdev =  np.std(result_df[col_name])
                to_write = learner + "," + "{:.2f}".format(rmse) + "," + "{:.2f}".format(result) + "\n"
                print("Writing " + to_write)
                file.write(to_write)

# %%
tested_datasets = ['airlines', 'wisdm', 'electricity','vavel_sup_slim', 'vavel_sup', 'rbf', 'hyperplane','led']
for ds in tested_datasets:
    runner = ExperimentRunner(ds)
    runner.run_standard_learners('20210831')
# Out:
# Running cmd = EvaluatePrequentialRegression -l (rules.functions.TargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff) -i 50000 -f 1000 -d runs/tuning/20210831/airlines/standard/rules.functions.TargetMean.csv
# Ran cmd with result 21.005371429137234
# Writing rules.functions.TargetMean,34.22,21.01
#
# Running cmd = EvaluatePrequentialRegression -l (rules.functions.FadingTargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff) -i 50000 -f 1000 -d runs/tuning/20210831/airlines/standard/rules.functions.FadingTargetMean.csv
# Ran cmd with result 20.00587052835034
# Writing rules.functions.FadingTargetMean,33.47,20.01
#
# Running cmd = EvaluatePrequentialRegression -l (functions.AdaGrad) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff) -i 50000 -f 1000 -d runs/tuning/20210831/airlines/standard/functions.AdaGrad.csv
# Ran cmd with result 19.90536063918401
# Writing functions.AdaGrad,33.31,19.91
#
# Running cmd = EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -s 10) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff) -i 50000 -f 1000 -d runs/tuning/20210831/airlines/standard/meta.AdaptiveRandomForestRegressor-s10.csv
# Ran cmd with result 19.47215748601945
# Writing meta.AdaptiveRandomForestRegressor -s 10,33.42,19.47
#
# Running cmd = EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff) -i 50000 -f 1000 -d runs/tuning/20210831/airlines/standard/meta.AdaptiveRandomForestRegressor-s10-m80.csv
# Ran cmd with result 19.581624611990687
# Writing meta.AdaptiveRandomForestRegressor -s 10 -m 80,33.53,19.58
#
# Running cmd = EvaluatePrequentialRegression -l (rules.AMRulesRegressor) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff) -i 50000 -f 1000 -d runs/tuning/20210831/airlines/standard/rules.AMRulesRegressor.csv
# Ran cmd with result 18.990405631030224
# Writing rules.AMRulesRegressor,33.10,18.99
#
# Running cmd = EvaluatePrequentialRegression -l (trees.ARFFIMTDD) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff) -i 50000 -f 1000 -d runs/tuning/20210831/airlines/standard/trees.ARFFIMTDD.csv
# Ran cmd with result 21.875893659286124
# Writing trees.ARFFIMTDD,34.32,21.88
#
# Running cmd = EvaluatePrequential -l (functions.MajorityClass) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5000 -f 1000 -d runs/tuning/20210831/wisdm/standard/functions.MajorityClass.csv
# Ran cmd with result 38.68
# Writing functions.MajorityClass,0.00,38.68
#
# Running cmd = EvaluatePrequential -l (functions.NoChange) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5000 -f 1000 -d runs/tuning/20210831/wisdm/standard/functions.NoChange.csv
# Ran cmd with result 93.02000000000001
# Writing functions.NoChange,0.00,93.02
#
# Running cmd = EvaluatePrequential -l (lazy.SAMkNN) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5000 -f 1000 -d runs/tuning/20210831/wisdm/standard/lazy.SAMkNN.csv
# Ran cmd with result 53.32000000000001
# Writing lazy.SAMkNN,0.00,53.32
#
# Running cmd = EvaluatePrequential -l (bayes.NaiveBayes) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5000 -f 1000 -d runs/tuning/20210831/wisdm/standard/bayes.NaiveBayes.csv
# Ran cmd with result 75.52
# Writing bayes.NaiveBayes,0.00,75.52
#
# Running cmd = EvaluatePrequential -l (meta.AdaptiveRandomForest -s 10) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5000 -f 1000 -d runs/tuning/20210831/wisdm/standard/meta.AdaptiveRandomForest-s10.csv
# Ran cmd with result 84.97999999999999
# Writing meta.AdaptiveRandomForest -s 10,0.00,84.98
#
# Running cmd = EvaluatePrequential -l (meta.AdaptiveRandomForest -s 10 -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5000 -f 1000 -d runs/tuning/20210831/wisdm/standard/meta.AdaptiveRandomForest-s10-m80.csv
# Ran cmd with result 84.35999999999999
# Writing meta.AdaptiveRandomForest -s 10 -m 80,0.00,84.36
#
# Running cmd = EvaluatePrequential -l (trees.HoeffdingAdaptiveTree) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5000 -f 1000 -d runs/tuning/20210831/wisdm/standard/trees.HoeffdingAdaptiveTree.csv
# Ran cmd with result 75.24
# Writing trees.HoeffdingAdaptiveTree,0.00,75.24
#
# Running cmd = EvaluatePrequential -l (meta.OzaBagAdwin) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5000 -f 1000 -d runs/tuning/20210831/wisdm/standard/meta.OzaBagAdwin.csv
# Ran cmd with result 78.47999999999999
# Writing meta.OzaBagAdwin,0.00,78.48
#
# Running cmd = EvaluatePrequential -l (functions.MajorityClass) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff) -i 45000 -f 1000 -d runs/tuning/20210831/electricity/standard/functions.MajorityClass.csv
# Ran cmd with result 57.604444444444454
# Writing functions.MajorityClass,0.00,57.60
#
# Running cmd = EvaluatePrequential -l (functions.NoChange) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff) -i 45000 -f 1000 -d runs/tuning/20210831/electricity/standard/functions.NoChange.csv
# Ran cmd with result 85.35555555555554
# Writing functions.NoChange,0.00,85.36
#
# Running cmd = EvaluatePrequential -l (lazy.SAMkNN) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff) -i 45000 -f 1000 -d runs/tuning/20210831/electricity/standard/lazy.SAMkNN.csv
# Ran cmd with result 82.83777777777776
# Writing lazy.SAMkNN,0.00,82.84
#
# Running cmd = EvaluatePrequential -l (bayes.NaiveBayes) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff) -i 45000 -f 1000 -d runs/tuning/20210831/electricity/standard/bayes.NaiveBayes.csv
# Ran cmd with result 73.33111111111111
# Writing bayes.NaiveBayes,0.00,73.33
#
# Running cmd = EvaluatePrequential -l (meta.AdaptiveRandomForest -s 10) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff) -i 45000 -f 1000 -d runs/tuning/20210831/electricity/standard/meta.AdaptiveRandomForest-s10.csv
# Ran cmd with result 89.96444444444444
# Writing meta.AdaptiveRandomForest -s 10,0.00,89.96
#
# Running cmd = EvaluatePrequential -l (meta.AdaptiveRandomForest -s 10 -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff) -i 45000 -f 1000 -d runs/tuning/20210831/electricity/standard/meta.AdaptiveRandomForest-s10-m80.csv
# Ran cmd with result 89.72
# Writing meta.AdaptiveRandomForest -s 10 -m 80,0.00,89.72
#
# Running cmd = EvaluatePrequential -l (trees.HoeffdingAdaptiveTree) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff) -i 45000 -f 1000 -d runs/tuning/20210831/electricity/standard/trees.HoeffdingAdaptiveTree.csv
# Ran cmd with result 83.45777777777779
# Writing trees.HoeffdingAdaptiveTree,0.00,83.46
#
# Running cmd = EvaluatePrequential -l (meta.OzaBagAdwin) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff) -i 45000 -f 1000 -d runs/tuning/20210831/electricity/standard/meta.OzaBagAdwin.csv
# Ran cmd with result 84.39333333333333
# Writing meta.OzaBagAdwin,0.00,84.39
#
# Running cmd = EvaluatePrequentialRegression -l (rules.functions.TargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff) -i 50000 -f 1000 -d runs/tuning/20210831/vavel_sup_slim/standard/rules.functions.TargetMean.csv
# Ran cmd with result 123.53953140069265
# Writing rules.functions.TargetMean,235.74,123.54
#
# Running cmd = EvaluatePrequentialRegression -l (rules.functions.FadingTargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff) -i 50000 -f 1000 -d runs/tuning/20210831/vavel_sup_slim/standard/rules.functions.FadingTargetMean.csv
# Ran cmd with result 131.76757786028548
# Writing rules.functions.FadingTargetMean,226.60,131.77
#
# Running cmd = EvaluatePrequentialRegression -l (functions.AdaGrad) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff) -i 50000 -f 1000 -d runs/tuning/20210831/vavel_sup_slim/standard/functions.AdaGrad.csv
# Ran cmd with result 16772.156525531493
# Writing functions.AdaGrad,123384.31,16772.16
#
# Running cmd = EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -s 10) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff) -i 50000 -f 1000 -d runs/tuning/20210831/vavel_sup_slim/standard/meta.AdaptiveRandomForestRegressor-s10.csv
# Ran cmd with result 50.117163543724864
# Writing meta.AdaptiveRandomForestRegressor -s 10,140.23,50.12
#
# Running cmd = EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff) -i 50000 -f 1000 -d runs/tuning/20210831/vavel_sup_slim/standard/meta.AdaptiveRandomForestRegressor-s10-m80.csv
# Ran cmd with result 48.282737376413046
# Writing meta.AdaptiveRandomForestRegressor -s 10 -m 80,136.77,48.28
#
# Running cmd = EvaluatePrequentialRegression -l (rules.AMRulesRegressor) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff) -i 50000 -f 1000 -d runs/tuning/20210831/vavel_sup_slim/standard/rules.AMRulesRegressor.csv
# Ran cmd with result 156.77867647651306
# Writing rules.AMRulesRegressor,3142.81,156.78
#
# Running cmd = EvaluatePrequentialRegression -l (trees.ARFFIMTDD) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff) -i 50000 -f 1000 -d runs/tuning/20210831/vavel_sup_slim/standard/trees.ARFFIMTDD.csv
# Ran cmd with result 81.08695802038338
# Writing trees.ARFFIMTDD,170.81,81.09
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-2e4f8b5bafc4> in <module>
#       1 tested_datasets = ['airlines', 'wisdm', 'electricity','vavel_sup_slim', 'vavel_sup', 'rbf', 'hyperplane','led']
#       2 for ds in tested_datasets:
# ----> 3     runner = ExperimentRunner(ds)
#       4     runner.run_standard_learners('20210831')
#
# <ipython-input-21-d137342e7882> in __init__(self, dataset)
#      32         self.test_quotient = 1
#      33         self.dataset = dataset
# ---> 34         self.exp_args = get_args(datasets[dataset])
#      35         self.task = 'EvaluatePrequential' if self.exp_args['classification'] else 'EvaluatePrequentialRegression'
#      36         self.learner = 'BufferLearner'
#
# <ipython-input-7-ab2bfa5ed0b4> in get_args(dataset)
#      19         'supervised': dataset[3],
#      20         'filebased': dataset[4],
# ---> 21         'partition_ids': dataset[5],
#      22         'time_ids': dataset[6],
#      23         'buffer_ids': dataset[7],
#
# IndexError: tuple index out of range

# %%
runner = ExperimentRunner('wisdm')
runner.run_standard_learners('20210831_test')
# Out:
# Running cmd = EvaluatePrequential -l (functions.MajorityClass) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5 -f 1 -d runs/tuning/20210831_test/wisdm/standard/functions.MajorityClass.csv
# Ran cmd with result 41.33333333333333
# Writing functions.MajorityClass,0.00,41.33
#
# Running cmd = EvaluatePrequential -l (functions.NoChange) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5 -f 1 -d runs/tuning/20210831_test/wisdm/standard/functions.NoChange.csv
# Ran cmd with result 45.33333333333333
# Writing functions.NoChange,0.00,45.33
#
# Running cmd = EvaluatePrequential -l (lazy.SAMkNN) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5 -f 1 -d runs/tuning/20210831_test/wisdm/standard/lazy.SAMkNN.csv
# Ran cmd with result 41.33333333333333
# Writing lazy.SAMkNN,0.00,41.33
#
# Running cmd = EvaluatePrequential -l (bayes.NaiveBayes) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5 -f 1 -d runs/tuning/20210831_test/wisdm/standard/bayes.NaiveBayes.csv
# Ran cmd with result 13.0
# Writing bayes.NaiveBayes,0.00,13.00
#
# Running cmd = EvaluatePrequential -l (meta.AdaptiveRandomForest -s 10) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5 -f 1 -d runs/tuning/20210831_test/wisdm/standard/meta.AdaptiveRandomForest-s10.csv
# Ran cmd with result 15.666666666666666
# Writing meta.AdaptiveRandomForest -s 10,0.00,15.67
#
# Running cmd = EvaluatePrequential -l (meta.AdaptiveRandomForest -s 10 -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5 -f 1 -d runs/tuning/20210831_test/wisdm/standard/meta.AdaptiveRandomForest-s10-m80.csv
# Ran cmd with result 15.666666666666666
# Writing meta.AdaptiveRandomForest -s 10 -m 80,0.00,15.67
#
# Running cmd = EvaluatePrequential -l (trees.HoeffdingAdaptiveTree) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5 -f 1 -d runs/tuning/20210831_test/wisdm/standard/trees.HoeffdingAdaptiveTree.csv
# Ran cmd with result 15.666666666666666
# Writing trees.HoeffdingAdaptiveTree,0.00,15.67
#
# Running cmd = EvaluatePrequential -l (meta.OzaBagAdwin) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff) -i 5 -f 1 -d runs/tuning/20210831_test/wisdm/standard/meta.OzaBagAdwin.csv
# Ran cmd with result 15.666666666666666
# Writing meta.OzaBagAdwin,0.00,15.67

# %%
runner = ExperimentRunner('electricity')
runner.run()
# Out:
# ['naive', 'trees.HoeffdingAdaptiveTree', 28, 25, -1, '0,2', '-1', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (trees.HoeffdingAdaptiveTree) -n 28 -m (functions.AdaGrad) -c naive -r 0.30000000000000004 -b relevance -p -1 -t 0,2 -y -1 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/treesHoeffdingAdaptiveTree_28_25_-1_0,2_-1_clustream_relevance_30.csv
# Ran cmd with result 60.668371578977926
# Writing naive,trees.HoeffdingAdaptiveTree,28,25,-1,0,2,-1,clustream,relevance,0.30000000000000004,13.59,60.67
#
# ['naive', 'meta.OzaBagAdwin', 12, 2, -1, '0,2', '-1', 'clustream', 'random', 1.0]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.OzaBagAdwin) -n 12 -m (functions.AdaGrad) -c naive -r 1.0 -b random -p -1 -t 0,2 -y -1 -q clustream -x 2) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaOzaBagAdwin_12_2_-1_0,2_-1_clustream_random_100.csv
# Ran cmd with result 64.82228866756881
# Writing naive,meta.OzaBagAdwin,12,2,-1,0,2,-1,clustream,random,1.0,12.24,64.82
#
# ['naive', 'trees.HoeffdingAdaptiveTree', 18, 5, 1, '0,2', '-1', 'clustream', 'relevance', 0.25]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (trees.HoeffdingAdaptiveTree) -n 18 -m (functions.AdaGrad) -c naive -r 0.25 -b relevance -p 1 -t 0,2 -y -1 -q clustream -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/treesHoeffdingAdaptiveTree_18_5_1_0,2_-1_clustream_relevance_25.csv
# Ran cmd with result 60.668371578977926
# Writing naive,trees.HoeffdingAdaptiveTree,18,5,1,0,2,-1,clustream,relevance,0.25,13.59,60.67
#
# ['naive', 'bayes.NaiveBayes', 28, 25, 1, '0,2', '-1', 'clustree', 'random', 0.35000000000000003]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (bayes.NaiveBayes) -n 28 -m (functions.AdaGrad) -c naive -r 0.35000000000000003 -b random -p 1 -t 0,2 -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/bayesNaiveBayes_28_25_1_0,2_-1_clustree_random_35.csv
# Ran cmd with result 52.60195354433551
# Writing naive,bayes.NaiveBayes,28,25,1,0,2,-1,clustree,random,0.35000000000000003,16.43,52.60
#
# ['naive', 'meta.AdaptiveRandomForest -s 10 -m 80', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10-m80_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 78.22541930494104
# Writing naive,meta.AdaptiveRandomForest -s 10 -m 80,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,10.03,78.23
#
# ['naive', 'bayes.NaiveBayes', 18, 4, -1, '0,2', '-1', 'clustream', 'random', 0.9]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (bayes.NaiveBayes) -n 18 -m (functions.AdaGrad) -c naive -r 0.9 -b random -p -1 -t 0,2 -y -1 -q clustream -x 4) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/bayesNaiveBayes_18_4_-1_0,2_-1_clustream_random_90.csv
# Ran cmd with result 54.650530473542716
# Writing naive,bayes.NaiveBayes,18,4,-1,0,2,-1,clustream,random,0.9,16.19,54.65
#
# ['naive', 'lazy.SAMkNN', 18, 25, 1, '0,2', '-1', 'clustree', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (lazy.SAMkNN) -n 18 -m (functions.AdaGrad) -c naive -r 0.30000000000000004 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/lazySAMkNN_18_25_1_0,2_-1_clustree_relevance_30.csv
# Ran cmd with result 74.1296039592395
# Writing naive,lazy.SAMkNN,18,25,1,0,2,-1,clustree,relevance,0.30000000000000004,9.14,74.13
#
# ['naive', 'meta.AdaptiveRandomForest -s 10 -m 80', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10 -m 80) -n 18 -m (functions.AdaGrad) -c naive -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10-m80_18_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 74.99876631028093
# Writing naive,meta.AdaptiveRandomForest -s 10 -m 80,18,10,1,0,2,-1,clustree,random,0.2,11.31,75.00
#
# ['naive', 'meta.OzaBagAdwin', 8, 3, -1, '0,2', '-1', 'clustream', 'relevance', 0.7000000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.OzaBagAdwin) -n 8 -m (functions.AdaGrad) -c naive -r 0.7000000000000001 -b relevance -p -1 -t 0,2 -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaOzaBagAdwin_8_3_-1_0,2_-1_clustream_relevance_70.csv
# Ran cmd with result 68.52397078352566
# Writing naive,meta.OzaBagAdwin,8,3,-1,0,2,-1,clustream,relevance,0.7000000000000001,11.00,68.52
#
# ['naive', 'functions.MajorityClass', 43, 1, 1, '0,2', '-1', 'clustree', 'relevance', 0.75]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (functions.MajorityClass) -n 43 -m (functions.AdaGrad) -c naive -r 0.75 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/functionsMajorityClass_43_1_1_0,2_-1_clustree_relevance_75.csv
# Ran cmd with result 52.55823755651878
# Writing naive,functions.MajorityClass,43,1,1,0,2,-1,clustree,relevance,0.75,16.47,52.56
#
# Params already ran - ['naive', 'meta.AdaptiveRandomForest -s 10 -m 80', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Params already ran - ['naive', 'meta.AdaptiveRandomForest -s 10 -m 80', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['naive', 'functions.MajorityClass', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (functions.MajorityClass) -n 5 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/functionsMajorityClass_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 52.55823755651878
# Writing naive,functions.MajorityClass,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,16.47,52.56
#
# ['naive', 'bayes.NaiveBayes', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (bayes.NaiveBayes) -n 5 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/bayesNaiveBayes_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 59.49243809013474
# Writing naive,bayes.NaiveBayes,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,14.60,59.49
#
# ['naive', 'trees.HoeffdingAdaptiveTree', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (trees.HoeffdingAdaptiveTree) -n 5 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/treesHoeffdingAdaptiveTree_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 60.668371578977926
# Writing naive,trees.HoeffdingAdaptiveTree,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,13.59,60.67
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 78.22541930494104
# Writing naive,meta.AdaptiveRandomForest -s 10,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,10.03,78.23
#
# ['naive', 'meta.OzaBagAdwin', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.OzaBagAdwin) -n 5 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaOzaBagAdwin_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 65.93198885347421
# Writing naive,meta.OzaBagAdwin,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,12.35,65.93
#
# Params already ran - ['naive', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['naive', 'meta.AdaptiveRandomForest -s 10', 28, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 28 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_28_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 74.99876631028093
# Writing naive,meta.AdaptiveRandomForest -s 10,28,7,1,0,2,-1,clustree,relevance,0.8500000000000001,11.31,75.00
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 65, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 65 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_65_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 64.673018184965
# Writing naive,meta.AdaptiveRandomForest -s 10,65,7,1,0,2,-1,clustree,relevance,0.8500000000000001,12.25,64.67
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,7,1,0,2,-1,clustree,relevance,0.8500000000000001,10.37,82.59
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 12, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 12 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_12_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 77.02064591260317
# Writing naive,meta.AdaptiveRandomForest -s 10,12,7,1,0,2,-1,clustree,relevance,0.8500000000000001,11.21,77.02
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 3, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_3_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,3,1,0,2,-1,clustree,relevance,0.8500000000000001,10.37,82.59
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 1, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_1_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,1,1,0,2,-1,clustree,relevance,0.8500000000000001,10.37,82.59
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 13, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_13_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,13,1,0,2,-1,clustree,relevance,0.8500000000000001,10.37,82.59
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 25, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_25_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,25,1,0,2,-1,clustree,relevance,0.8500000000000001,10.37,82.59
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 18, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 18) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_18_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,18,1,0,2,-1,clustree,relevance,0.8500000000000001,10.37,82.59
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, -1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p -1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_7_-1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,7,-1,0,2,-1,clustree,relevance,0.8500000000000001,10.37,82.59
#
# Params already ran - ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Params already ran - ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Params already ran - ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Params already ran - ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustream', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustream -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_7_1_0,2_-1_clustream_relevance_85.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,7,1,0,2,-1,clustream,relevance,0.8500000000000001,10.37,82.59
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'random', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.8500000000000001 -b random -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_7_1_0,2_-1_clustree_random_85.csv
# Ran cmd with result 74.47978860373873
# Writing naive,meta.AdaptiveRandomForest -s 10,8,7,1,0,2,-1,clustree,random,0.8500000000000001,11.75,74.48
#
# Params already ran - ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.4]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.4 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_7_1_0,2_-1_clustree_relevance_40.csv
# Ran cmd with result 79.89117355113791
# Writing naive,meta.AdaptiveRandomForest -s 10,8,7,1,0,2,-1,clustree,relevance,0.4,10.50,79.89
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.6000000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.6000000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_7_1_0,2_-1_clustree_relevance_60.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,7,1,0,2,-1,clustree,relevance,0.6000000000000001,10.37,82.59
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.1]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.1 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_7_1_0,2_-1_clustree_relevance_10.csv
# Ran cmd with result 77.3503162422735
# Writing naive,meta.AdaptiveRandomForest -s 10,8,7,1,0,2,-1,clustree,relevance,0.1,10.79,77.35
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.7000000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.7000000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_7_1_0,2_-1_clustree_relevance_70.csv
# Ran cmd with result 82.59076101873254
# Writing naive,meta.AdaptiveRandomForest -s 10,8,7,1,0,2,-1,clustree,relevance,0.7000000000000001,10.37,82.59
#
# ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c naive -r 0.25 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/naive/metaAdaptiveRandomForest-s10_8_7_1_0,2_-1_clustree_relevance_25.csv
# Ran cmd with result 77.3503162422735
# Writing naive,meta.AdaptiveRandomForest -s 10,8,7,1,0,2,-1,clustree,relevance,0.25,10.79,77.35
#
# Best params for naive: ['naive', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['cluster', 'trees.HoeffdingAdaptiveTree', 28, 25, -1, '0,2', '-1', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (trees.HoeffdingAdaptiveTree) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,2 -y -1 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/treesHoeffdingAdaptiveTree_28_25_-1_0,2_-1_clustream_relevance_30.csv
# Ran cmd with result 75.74706437400502
# Writing cluster,trees.HoeffdingAdaptiveTree,28,25,-1,0,2,-1,clustream,relevance,0.30000000000000004,8.41,75.75
#
# ['cluster', 'meta.OzaBagAdwin', 12, 2, -1, '0,2', '-1', 'clustream', 'random', 1.0]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.OzaBagAdwin) -n 12 -m (functions.AdaGrad) -c cluster -r 1.0 -b random -p -1 -t 0,2 -y -1 -q clustream -x 2) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaOzaBagAdwin_12_2_-1_0,2_-1_clustream_random_100.csv
# Ran cmd with result 75.1862657593834
# Writing cluster,meta.OzaBagAdwin,12,2,-1,0,2,-1,clustream,random,1.0,9.95,75.19
#
# ['cluster', 'trees.HoeffdingAdaptiveTree', 18, 5, 1, '0,2', '-1', 'clustream', 'relevance', 0.25]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (trees.HoeffdingAdaptiveTree) -n 18 -m (functions.AdaGrad) -c cluster -r 0.25 -b relevance -p 1 -t 0,2 -y -1 -q clustream -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/treesHoeffdingAdaptiveTree_18_5_1_0,2_-1_clustream_relevance_25.csv
# Ran cmd with result 72.75998982656874
# Writing cluster,trees.HoeffdingAdaptiveTree,18,5,1,0,2,-1,clustream,relevance,0.25,9.25,72.76
#
# ['cluster', 'bayes.NaiveBayes', 28, 25, 1, '0,2', '-1', 'clustree', 'random', 0.35000000000000003]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (bayes.NaiveBayes) -n 28 -m (functions.AdaGrad) -c cluster -r 0.35000000000000003 -b random -p 1 -t 0,2 -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/bayesNaiveBayes_28_25_1_0,2_-1_clustree_random_35.csv
# Ran cmd with result 81.49774844384086
# Writing cluster,bayes.NaiveBayes,28,25,1,0,2,-1,clustree,random,0.35000000000000003,7.00,81.50
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10 -m 80', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10-m80_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 84.21328047458532
# Writing cluster,meta.AdaptiveRandomForest -s 10 -m 80,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,7.98,84.21
#
# ['cluster', 'bayes.NaiveBayes', 18, 4, -1, '0,2', '-1', 'clustream', 'random', 0.9]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (bayes.NaiveBayes) -n 18 -m (functions.AdaGrad) -c cluster -r 0.9 -b random -p -1 -t 0,2 -y -1 -q clustream -x 4) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/bayesNaiveBayes_18_4_-1_0,2_-1_clustream_random_90.csv
# Ran cmd with result 79.00906488484776
# Writing cluster,bayes.NaiveBayes,18,4,-1,0,2,-1,clustream,random,0.9,7.23,79.01
#
# ['cluster', 'lazy.SAMkNN', 18, 25, 1, '0,2', '-1', 'clustree', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (lazy.SAMkNN) -n 18 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/lazySAMkNN_18_25_1_0,2_-1_clustree_relevance_30.csv
# Ran cmd with result 62.49801919319072
# Writing cluster,lazy.SAMkNN,18,25,1,0,2,-1,clustree,relevance,0.30000000000000004,13.11,62.50
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10 -m 80', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10 -m 80) -n 18 -m (functions.AdaGrad) -c cluster -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10-m80_18_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 65.22319989193062
# Writing cluster,meta.AdaptiveRandomForest -s 10 -m 80,18,10,1,0,2,-1,clustree,random,0.2,12.78,65.22
#
# ['cluster', 'meta.OzaBagAdwin', 8, 3, -1, '0,2', '-1', 'clustream', 'relevance', 0.7000000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.OzaBagAdwin) -n 8 -m (functions.AdaGrad) -c cluster -r 0.7000000000000001 -b relevance -p -1 -t 0,2 -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaOzaBagAdwin_8_3_-1_0,2_-1_clustream_relevance_70.csv
# Ran cmd with result 67.74429055518247
# Writing cluster,meta.OzaBagAdwin,8,3,-1,0,2,-1,clustream,relevance,0.7000000000000001,11.94,67.74
#
# ['cluster', 'functions.MajorityClass', 43, 1, 1, '0,2', '-1', 'clustree', 'relevance', 0.75]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (functions.MajorityClass) -n 43 -m (functions.AdaGrad) -c cluster -r 0.75 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/functionsMajorityClass_43_1_1_0,2_-1_clustree_relevance_75.csv
# Ran cmd with result 52.55823755651878
# Writing cluster,functions.MajorityClass,43,1,1,0,2,-1,clustree,relevance,0.75,16.47,52.56
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForest -s 10 -m 80', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Params already ran - ['cluster', 'meta.AdaptiveRandomForest -s 10 -m 80', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['cluster', 'functions.MajorityClass', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (functions.MajorityClass) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/functionsMajorityClass_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 52.55823755651878
# Writing cluster,functions.MajorityClass,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,16.47,52.56
#
# ['cluster', 'bayes.NaiveBayes', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (bayes.NaiveBayes) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/bayesNaiveBayes_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 82.04922999169523
# Writing cluster,bayes.NaiveBayes,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,7.16,82.05
#
# ['cluster', 'trees.HoeffdingAdaptiveTree', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (trees.HoeffdingAdaptiveTree) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/treesHoeffdingAdaptiveTree_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 68.03224884626957
# Writing cluster,trees.HoeffdingAdaptiveTree,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,12.00,68.03
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,7.17,87.47
#
# ['cluster', 'meta.OzaBagAdwin', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.OzaBagAdwin) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaOzaBagAdwin_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 82.04922999169523
# Writing cluster,meta.OzaBagAdwin,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,7.16,82.05
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 28, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 28 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_28_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,28,7,1,0,2,-1,clustree,relevance,0.8500000000000001,7.17,87.47
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 65, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 65 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_65_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,65,7,1,0,2,-1,clustree,relevance,0.8500000000000001,7.17,87.47
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 8, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_8_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,8,7,1,0,2,-1,clustree,relevance,0.8500000000000001,7.17,87.47
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 12, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 12 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_12_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,12,7,1,0,2,-1,clustree,relevance,0.8500000000000001,7.17,87.47
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 3, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_3_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 84.21328047458532
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,3,1,0,2,-1,clustree,relevance,0.8500000000000001,7.98,84.21
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 1, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_1_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 67.9124463350403
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,1,1,0,2,-1,clustree,relevance,0.8500000000000001,13.15,67.91
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 13, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_13_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 76.84513598998394
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,13,1,0,2,-1,clustree,relevance,0.8500000000000001,9.64,76.85
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 25, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_25_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 63.05987399759613
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,25,1,0,2,-1,clustree,relevance,0.8500000000000001,14.15,63.06
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 18, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 18) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_18_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 67.90315395669182
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,18,1,0,2,-1,clustree,relevance,0.8500000000000001,11.38,67.90
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, -1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p -1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_7_-1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,7,-1,0,2,-1,clustree,relevance,0.8500000000000001,7.17,87.47
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Params already ran - ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Params already ran - ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Params already ran - ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustream', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustream -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_7_1_0,2_-1_clustream_relevance_85.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,7,1,0,2,-1,clustream,relevance,0.8500000000000001,7.17,87.47
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'random', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.8500000000000001 -b random -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_7_1_0,2_-1_clustree_random_85.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,7,1,0,2,-1,clustree,random,0.8500000000000001,7.17,87.47
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.4]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.4 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_7_1_0,2_-1_clustree_relevance_40.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,7,1,0,2,-1,clustree,relevance,0.4,7.17,87.47
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.6000000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.6000000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_7_1_0,2_-1_clustree_relevance_60.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,7,1,0,2,-1,clustree,relevance,0.6000000000000001,7.17,87.47
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.1]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.1 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_7_1_0,2_-1_clustree_relevance_10.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,7,1,0,2,-1,clustree,relevance,0.1,7.17,87.47
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.7000000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.7000000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_7_1_0,2_-1_clustree_relevance_70.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,7,1,0,2,-1,clustree,relevance,0.7000000000000001,7.17,87.47
#
# ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.25 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cluster/metaAdaptiveRandomForest-s10_5_7_1_0,2_-1_clustree_relevance_25.csv
# Ran cmd with result 87.47101350032544
# Writing cluster,meta.AdaptiveRandomForest -s 10,5,7,1,0,2,-1,clustree,relevance,0.25,7.17,87.47
#
# Best params for cluster: ['cluster', 'meta.AdaptiveRandomForest -s 10', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# ['featureExtraction', 'trees.HoeffdingAdaptiveTree', 28, 25, -1, '0,2', '-1', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (trees.HoeffdingAdaptiveTree) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.30000000000000004 -b relevance -p -1 -t 0,2 -y -1 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/featureExtraction/treesHoeffdingAdaptiveTree_28_25_-1_0,2_-1_clustream_relevance_30.csv
# Ran cmd with result 60.668371578977926
# Writing featureExtraction,trees.HoeffdingAdaptiveTree,28,25,-1,0,2,-1,clustream,relevance,0.30000000000000004,13.59,60.67
#
# ['featureExtraction', 'meta.OzaBagAdwin', 12, 2, -1, '0,2', '-1', 'clustream', 'random', 1.0]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.OzaBagAdwin) -n 12 -m (functions.AdaGrad) -c featureExtraction -r 1.0 -b random -p -1 -t 0,2 -y -1 -q clustream -x 2) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/featureExtraction/metaOzaBagAdwin_12_2_-1_0,2_-1_clustream_random_100.csv
# Ran cmd with result 60.15692204161932
# Writing featureExtraction,meta.OzaBagAdwin,12,2,-1,0,2,-1,clustream,random,1.0,14.05,60.16
#
# ['featureExtraction', 'trees.HoeffdingAdaptiveTree', 18, 5, 1, '0,2', '-1', 'clustream', 'relevance', 0.25]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (trees.HoeffdingAdaptiveTree) -n 18 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p 1 -t 0,2 -y -1 -q clustream -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/featureExtraction/treesHoeffdingAdaptiveTree_18_5_1_0,2_-1_clustream_relevance_25.csv
# Ran cmd with result 60.668371578977926
# Writing featureExtraction,trees.HoeffdingAdaptiveTree,18,5,1,0,2,-1,clustream,relevance,0.25,13.59,60.67
#
# ['featureExtraction', 'bayes.NaiveBayes', 28, 25, 1, '0,2', '-1', 'clustree', 'random', 0.35000000000000003]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (bayes.NaiveBayes) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.35000000000000003 -b random -p 1 -t 0,2 -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/featureExtraction/bayesNaiveBayes_28_25_1_0,2_-1_clustree_random_35.csv
# Ran cmd with result 52.92987520146669
# Writing featureExtraction,bayes.NaiveBayes,28,25,1,0,2,-1,clustree,random,0.35000000000000003,16.37,52.93
#
# ['featureExtraction', 'meta.AdaptiveRandomForest -s 10 -m 80', 5, 7, 1, '0,2', '-1', 'clustree', 'relevance', 0.8500000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.8500000000000001 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/featureExtraction/metaAdaptiveRandomForest-s10-m80_5_7_1_0,2_-1_clustree_relevance_85.csv
# Ran cmd with result 77.0258937331772
# Writing featureExtraction,meta.AdaptiveRandomForest -s 10 -m 80,5,7,1,0,2,-1,clustree,relevance,0.8500000000000001,9.72,77.03
#
# ['featureExtraction', 'bayes.NaiveBayes', 18, 4, -1, '0,2', '-1', 'clustream', 'random', 0.9]
# ...
# Ran cmd with result 77.26236035462672
# Writing cep,meta.OzaBagAdwin,8,3,-1,0,2,-1,clustream,relevance,0.7000000000000001,7.74,77.26
#
# ['cep', 'functions.MajorityClass', 43, 1, 1, '0,2', '-1', 'clustree', 'relevance', 0.75]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (functions.MajorityClass) -n 43 -m (functions.AdaGrad) -c cep -r 0.75 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/functionsMajorityClass_43_1_1_0,2_-1_clustree_relevance_75.csv
# Ran cmd with result 52.55823755651878
# Writing cep,functions.MajorityClass,43,1,1,0,2,-1,clustree,relevance,0.75,16.47,52.56
#
# Params already ran - ['cep', 'meta.AdaptiveRandomForest -s 10 -m 80', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Params already ran - ['cep', 'meta.AdaptiveRandomForest -s 10 -m 80', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# ['cep', 'functions.MajorityClass', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (functions.MajorityClass) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/functionsMajorityClass_18_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 52.55823755651878
# Writing cep,functions.MajorityClass,18,10,1,0,2,-1,clustree,random,0.2,16.47,52.56
#
# ['cep', 'bayes.NaiveBayes', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (bayes.NaiveBayes) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/bayesNaiveBayes_18_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 82.04922999169523
# Writing cep,bayes.NaiveBayes,18,10,1,0,2,-1,clustree,random,0.2,7.16,82.05
#
# ['cep', 'trees.HoeffdingAdaptiveTree', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (trees.HoeffdingAdaptiveTree) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/treesHoeffdingAdaptiveTree_18_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 75.61188772269934
# Writing cep,trees.HoeffdingAdaptiveTree,18,10,1,0,2,-1,clustree,random,0.2,8.46,75.61
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,18,10,1,0,2,-1,clustree,random,0.2,7.34,90.17
#
# ['cep', 'meta.OzaBagAdwin', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.OzaBagAdwin) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaOzaBagAdwin_18_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 82.04922999169523
# Writing cep,meta.OzaBagAdwin,18,10,1,0,2,-1,clustree,random,0.2,7.16,82.05
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 5, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 5 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_5_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,5,10,1,0,2,-1,clustree,random,0.2,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 28, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 28 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_28_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,28,10,1,0,2,-1,clustree,random,0.2,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 65, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 65 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_65_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,65,10,1,0,2,-1,clustree,random,0.2,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 8, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 8 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_8_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,8,10,1,0,2,-1,clustree,random,0.2,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 12, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 12 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_12_10_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,12,10,1,0,2,-1,clustree,random,0.2,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 3, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_3_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 72.8308141214309
# Writing cep,meta.AdaptiveRandomForest -s 10,18,3,1,0,2,-1,clustree,random,0.2,13.67,72.83
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 1, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_1_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 72.91674572090324
# Writing cep,meta.AdaptiveRandomForest -s 10,18,1,1,0,2,-1,clustree,random,0.2,9.22,72.92
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 13, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_13_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 84.21328047458532
# Writing cep,meta.AdaptiveRandomForest -s 10,18,13,1,0,2,-1,clustree,random,0.2,7.98,84.21
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 25, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_25_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 73.98033347663568
# Writing cep,meta.AdaptiveRandomForest -s 10,18,25,1,0,2,-1,clustree,random,0.2,9.11,73.98
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 18, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustree -x 18) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_18_1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 76.84513598998394
# Writing cep,meta.AdaptiveRandomForest -s 10,18,18,1,0,2,-1,clustree,random,0.2,9.64,76.85
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, -1, '0,2', '-1', 'clustree', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p -1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_10_-1_0,2_-1_clustree_random_20.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,18,10,-1,0,2,-1,clustree,random,0.2,7.34,90.17
#
# Params already ran - ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Params already ran - ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Params already ran - ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# Params already ran - ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustream', 'random', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b random -p 1 -t 0,2 -y -1 -q clustream -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_10_1_0,2_-1_clustream_random_20.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,18,10,1,0,2,-1,clustream,random,0.2,7.34,90.17
#
# Params already ran - ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'relevance', 0.2]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.2 -b relevance -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_10_1_0,2_-1_clustree_relevance_20.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,18,10,1,0,2,-1,clustree,relevance,0.2,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.4]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.4 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_10_1_0,2_-1_clustree_random_40.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,18,10,1,0,2,-1,clustree,random,0.4,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.6000000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.6000000000000001 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_10_1_0,2_-1_clustree_random_60.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,18,10,1,0,2,-1,clustree,random,0.6000000000000001,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.1]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.1 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_10_1_0,2_-1_clustree_random_10.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,18,10,1,0,2,-1,clustree,random,0.1,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.7000000000000001]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.7000000000000001 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_10_1_0,2_-1_clustree_random_70.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,18,10,1,0,2,-1,clustree,random,0.7000000000000001,7.34,90.17
#
# ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 1 -t 0,2 -y -1 -q clustree -x 10) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/electricity_arff.arff) -i 45 -f 1 -d runs/tuning/20210831_test/electricity/cep/metaAdaptiveRandomForest-s10_18_10_1_0,2_-1_clustree_random_25.csv
# Ran cmd with result 90.17060096792005
# Writing cep,meta.AdaptiveRandomForest -s 10,18,10,1,0,2,-1,clustree,random,0.25,7.34,90.17
#
# Best params for cep: ['cep', 'meta.AdaptiveRandomForest -s 10', 18, 10, 1, '0,2', '-1', 'clustree', 'random', 0.2]

# %%
runner = ExperimentRunner('airlines')
runner.run()
# Out:
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 25, -1, '', '-1', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1  -y -1 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10_28_25_-1__-1_clustream_relevance_30.csv
# Ran cmd with result 17.403898239550003
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10,28,25,-1,,-1,clustream,relevance,0.30000000000000004,2.85,17.40
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 17.362325547832995
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,7,-1,,-1,clustree,relevance,0.25,2.77,17.36
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 18, 5, 10, '', '-1', 'clustree', 'relevance', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 18 -m (functions.AdaGrad) -c cluster -r 0.6000000000000001 -b relevance -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10_18_5_10__-1_clustree_relevance_60.csv
# Ran cmd with result 17.381953735926114
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10,18,5,10,,-1,clustree,relevance,0.6000000000000001,2.68,17.38
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.03246315248836
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10,5,13,10,,-1,clustree,random,0.25,2.85,17.03
#
# ['cluster', 'functions.AdaGrad', 43, 7, -1, '', '-1', 'clustream', 'relevance', 0.15000000000000002]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 43 -m (functions.AdaGrad) -c cluster -r 0.15000000000000002 -b relevance -p -1  -y -1 -q clustream -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/functionsAdaGrad_43_7_-1__-1_clustream_relevance_15.csv
# Ran cmd with result 27.483471859615168
# Writing cluster,functions.AdaGrad,43,7,-1,,-1,clustream,relevance,0.15000000000000002,12.34,27.48
#
# ['cluster', 'trees.ARFFIMTDD', 43, 3, -1, '', '-1', 'clustree', 'random', 0.8]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 43 -m (functions.AdaGrad) -c cluster -r 0.8 -b random -p -1  -y -1 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/treesARFFIMTDD_43_3_-1__-1_clustree_random_80.csv
# Ran cmd with result 17.373668417695
# Writing cluster,trees.ARFFIMTDD,43,3,-1,,-1,clustree,random,0.8,2.67,17.37
#
# ['cluster', 'trees.ARFFIMTDD', 65, 2, 10, '', '-1', 'clustream', 'relevance', 1.0]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 65 -m (functions.AdaGrad) -c cluster -r 1.0 -b relevance -p 10  -y -1 -q clustream -x 2) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/treesARFFIMTDD_65_2_10__-1_clustream_relevance_100.csv
# Ran cmd with result 17.373668417695
# Writing cluster,trees.ARFFIMTDD,65,2,10,,-1,clustream,relevance,1.0,2.67,17.37
#
# ['cluster', 'rules.functions.TargetMean', 2, 13, -1, '', '-1', 'clustream', 'relevance', 0.75]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 2 -m (functions.AdaGrad) -c cluster -r 0.75 -b relevance -p -1  -y -1 -q clustream -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/rulesfunctionsTargetMean_2_13_-1__-1_clustream_relevance_75.csv
# Ran cmd with result 17.373668417695
# Writing cluster,rules.functions.TargetMean,2,13,-1,,-1,clustream,relevance,0.75,2.67,17.37
#
# ['cluster', 'rules.AMRulesRegressor', 8, 3, 10, '', '-1', 'clustream', 'relevance', 0.5]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 8 -m (functions.AdaGrad) -c cluster -r 0.5 -b relevance -p 10  -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/rulesAMRulesRegressor_8_3_10__-1_clustream_relevance_50.csv
# Ran cmd with result 17.373668417695
# Writing cluster,rules.AMRulesRegressor,8,3,10,,-1,clustream,relevance,0.5,2.67,17.37
#
# ['cluster', 'rules.AMRulesRegressor', 100, 3, -1, '', '-1', 'clustream', 'relevance', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 100 -m (functions.AdaGrad) -c cluster -r 0.4 -b relevance -p -1  -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/rulesAMRulesRegressor_100_3_-1__-1_clustream_relevance_40.csv
# Ran cmd with result 17.373668417695
# Writing cluster,rules.AMRulesRegressor,100,3,-1,,-1,clustream,relevance,0.4,2.67,17.37
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 16.978522376737583
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,13,10,,-1,clustree,random,0.25,2.82,16.98
#
# ['cluster', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/rulesfunctionsTargetMean_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cluster,rules.functions.TargetMean,5,13,10,,-1,clustree,random,0.25,2.67,17.37
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cluster', 'trees.ARFFIMTDD', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 5 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/treesARFFIMTDD_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cluster,trees.ARFFIMTDD,5,13,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cluster', 'functions.AdaGrad', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 5 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/functionsAdaGrad_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 27.480325315733502
# Writing cluster,functions.AdaGrad,5,13,10,,-1,clustree,random,0.25,12.34,27.48
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 1, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 1 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_1_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.963124682935675
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,1,13,10,,-1,clustree,random,0.25,2.79,17.96
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_13_10__-1_clustree_random_25.csv
# Ran cmd with result 16.974170562808293
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,13,10,,-1,clustree,random,0.25,2.82,16.97
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 43, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 43 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_43_13_10__-1_clustree_random_25.csv
# Ran cmd with result 16.974170562808293
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,43,13,10,,-1,clustree,random,0.25,2.82,16.97
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 18, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 18 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_18_13_10__-1_clustree_random_25.csv
# Ran cmd with result 16.974170562808293
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,18,13,10,,-1,clustree,random,0.25,2.82,16.97
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_10__-1_clustree_random_25.csv
# Ran cmd with result 16.351591992356646
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,10,,-1,clustree,random,0.25,2.88,16.35
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 3, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_3_10__-1_clustree_random_25.csv
# Ran cmd with result 17.246804230317718
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,3,10,,-1,clustree,random,0.25,2.88,17.25
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 1, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_1_10__-1_clustree_random_25.csv
# Ran cmd with result 17.381650515248026
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,1,10,,-1,clustree,random,0.25,2.86,17.38
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 25, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_25_10__-1_clustree_random_25.csv
# Ran cmd with result 17.45513747407019
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,25,10,,-1,clustree,random,0.25,2.77,17.46
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 4, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustree -x 4) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_4_10__-1_clustree_random_25.csv
# Ran cmd with result 17.497932525115974
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,4,10,,-1,clustree,random,0.25,2.77,17.50
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, -1, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p -1  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_-1__-1_clustree_random_25.csv
# Ran cmd with result 17.780512868277565
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,-1,,-1,clustree,random,0.25,2.87,17.78
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 9, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 9  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_9__-1_clustree_random_25.csv
# Ran cmd with result 16.396862558633405
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,9,,-1,clustree,random,0.25,2.90,16.40
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustream', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 10  -y -1 -q clustream -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_10__-1_clustream_random_25.csv
# Ran cmd with result 16.40093393943003
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,10,,-1,clustream,random,0.25,2.90,16.40
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b relevance -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_10__-1_clustree_relevance_25.csv
# Ran cmd with result 16.351591992356646
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,10,,-1,clustree,relevance,0.25,2.88,16.35
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.55]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.55 -b random -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_10__-1_clustree_random_55.csv
# Ran cmd with result 16.351591992356646
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,10,,-1,clustree,random,0.55,2.88,16.35
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.15000000000000002]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.15000000000000002 -b random -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_10__-1_clustree_random_15.csv
# Ran cmd with result 16.351591992356646
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,10,,-1,clustree,random,0.15000000000000002,2.88,16.35
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.4 -b random -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_10__-1_clustree_random_40.csv
# Ran cmd with result 16.351591992356646
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,10,,-1,clustree,random,0.4,2.88,16.35
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.6000000000000001 -b random -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_10__-1_clustree_random_60.csv
# Ran cmd with result 16.351591992356646
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,10,,-1,clustree,random,0.6000000000000001,2.88,16.35
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.1]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.1 -b random -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_5_10__-1_clustree_random_10.csv
# Ran cmd with result 16.351591992356646
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,5,10,,-1,clustree,random,0.1,2.88,16.35
#
# Best params for cluster: ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 5, 10, '', '-1', 'clustree', 'random', 0.25]
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 25, -1, '', '-1', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.30000000000000004 -b relevance -p -1  -y -1 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_28_25_-1__-1_clustream_relevance_30.csv
# Ran cmd with result 17.313547625485352
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,28,25,-1,,-1,clustream,relevance,0.30000000000000004,2.84,17.31
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_28_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 16.342701221939915
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,7,-1,,-1,clustree,relevance,0.25,2.84,16.34
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 18, 5, 10, '', '-1', 'clustree', 'relevance', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 18 -m (functions.AdaGrad) -c featureExtraction -r 0.6000000000000001 -b relevance -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_18_5_10__-1_clustree_relevance_60.csv
# Ran cmd with result 17.651724989263364
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,18,5,10,,-1,clustree,relevance,0.6000000000000001,2.74,17.65
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.41373116822639
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,5,13,10,,-1,clustree,random,0.25,2.71,17.41
#
# ['featureExtraction', 'functions.AdaGrad', 43, 7, -1, '', '-1', 'clustream', 'relevance', 0.15000000000000002]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.15000000000000002 -b relevance -p -1  -y -1 -q clustream -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/functionsAdaGrad_43_7_-1__-1_clustream_relevance_15.csv
# Ran cmd with result 27.481774912104598
# Writing featureExtraction,functions.AdaGrad,43,7,-1,,-1,clustream,relevance,0.15000000000000002,12.34,27.48
#
# ['featureExtraction', 'trees.ARFFIMTDD', 43, 3, -1, '', '-1', 'clustree', 'random', 0.8]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.8 -b random -p -1  -y -1 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/treesARFFIMTDD_43_3_-1__-1_clustree_random_80.csv
# Ran cmd with result 17.373668417695
# Writing featureExtraction,trees.ARFFIMTDD,43,3,-1,,-1,clustree,random,0.8,2.67,17.37
#
# ['featureExtraction', 'trees.ARFFIMTDD', 65, 2, 10, '', '-1', 'clustream', 'relevance', 1.0]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 65 -m (functions.AdaGrad) -c featureExtraction -r 1.0 -b relevance -p 10  -y -1 -q clustream -x 2) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/treesARFFIMTDD_65_2_10__-1_clustream_relevance_100.csv
# Ran cmd with result 17.373668417695
# Writing featureExtraction,trees.ARFFIMTDD,65,2,10,,-1,clustream,relevance,1.0,2.67,17.37
#
# ['featureExtraction', 'rules.functions.TargetMean', 2, 13, -1, '', '-1', 'clustream', 'relevance', 0.75]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 2 -m (functions.AdaGrad) -c featureExtraction -r 0.75 -b relevance -p -1  -y -1 -q clustream -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/rulesfunctionsTargetMean_2_13_-1__-1_clustream_relevance_75.csv
# Ran cmd with result 17.373668417695
# Writing featureExtraction,rules.functions.TargetMean,2,13,-1,,-1,clustream,relevance,0.75,2.67,17.37
#
# ['featureExtraction', 'rules.AMRulesRegressor', 8, 3, 10, '', '-1', 'clustream', 'relevance', 0.5]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 8 -m (functions.AdaGrad) -c featureExtraction -r 0.5 -b relevance -p 10  -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/rulesAMRulesRegressor_8_3_10__-1_clustream_relevance_50.csv
# Ran cmd with result 17.373668417695
# Writing featureExtraction,rules.AMRulesRegressor,8,3,10,,-1,clustream,relevance,0.5,2.67,17.37
#
# ['featureExtraction', 'rules.AMRulesRegressor', 100, 3, -1, '', '-1', 'clustream', 'relevance', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 100 -m (functions.AdaGrad) -c featureExtraction -r 0.4 -b relevance -p -1  -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/rulesAMRulesRegressor_100_3_-1__-1_clustream_relevance_40.csv
# Ran cmd with result 17.373668417695
# Writing featureExtraction,rules.AMRulesRegressor,100,3,-1,,-1,clustream,relevance,0.4,2.67,17.37
#
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# ['featureExtraction', 'rules.functions.TargetMean', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/rulesfunctionsTargetMean_28_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 17.373668417695
# Writing featureExtraction,rules.functions.TargetMean,28,7,-1,,-1,clustree,relevance,0.25,2.67,17.37
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_28_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 16.410683831116067
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,28,7,-1,,-1,clustree,relevance,0.25,2.80,16.41
#
# ['featureExtraction', 'trees.ARFFIMTDD', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/treesARFFIMTDD_28_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 17.373668417695
# Writing featureExtraction,trees.ARFFIMTDD,28,7,-1,,-1,clustree,relevance,0.25,2.67,17.37
#
# ['featureExtraction', 'functions.AdaGrad', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/functionsAdaGrad_28_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 27.42443105883675
# Writing featureExtraction,functions.AdaGrad,28,7,-1,,-1,clustree,relevance,0.25,12.37,27.42
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 1, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 1 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_1_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 17.7002664126057
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,1,7,-1,,-1,clustree,relevance,0.25,2.76,17.70
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_5_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 16.81634222918197
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,5,7,-1,,-1,clustree,relevance,0.25,2.71,16.82
#
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 16.357579696414337
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,-1,,-1,clustree,relevance,0.25,2.83,16.36
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 18, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 18 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_18_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 17.416526452334942
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,18,7,-1,,-1,clustree,relevance,0.25,2.75,17.42
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 5, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_5_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 16.357579696414337
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,5,-1,,-1,clustree,relevance,0.25,2.83,16.36
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 3, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_3_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 16.357579696414337
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,3,-1,,-1,clustree,relevance,0.25,2.83,16.36
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 1, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_1_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 16.357579696414337
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,1,-1,,-1,clustree,relevance,0.25,2.83,16.36
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 25, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_25_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 16.357579696414337
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,25,-1,,-1,clustree,relevance,0.25,2.83,16.36
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 4, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 4) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_4_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 16.357579696414337
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,4,-1,,-1,clustree,relevance,0.25,2.83,16.36
#
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, 9, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p 9  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_9__-1_clustree_relevance_25.csv
# Ran cmd with result 17.68347321845646
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,9,,-1,clustree,relevance,0.25,2.80,17.68
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, 10, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p 10  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_10__-1_clustree_relevance_25.csv
# Ran cmd with result 17.820968594425924
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,10,,-1,clustree,relevance,0.25,2.83,17.82
#
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustream', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1  -y -1 -q clustream -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_-1__-1_clustream_relevance_25.csv
# Ran cmd with result 17.504154415059716
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,-1,,-1,clustream,relevance,0.25,2.82,17.50
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_-1__-1_clustree_random_25.csv
# Ran cmd with result 16.347538297942048
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,-1,,-1,clustree,random,0.25,2.84,16.35
#
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'random', 0.55]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.55 -b random -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_-1__-1_clustree_random_55.csv
# Ran cmd with result 16.366373789662948
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,-1,,-1,clustree,random,0.55,2.83,16.37
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'random', 0.15000000000000002]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.15000000000000002 -b random -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_-1__-1_clustree_random_15.csv
# Ran cmd with result 16.35824516472158
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,-1,,-1,clustree,random,0.15000000000000002,2.83,16.36
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'random', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.4 -b random -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_-1__-1_clustree_random_40.csv
# Ran cmd with result 16.35327446372838
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,-1,,-1,clustree,random,0.4,2.84,16.35
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'random', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.6000000000000001 -b random -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_-1__-1_clustree_random_60.csv
# Ran cmd with result 16.366373789662948
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,-1,,-1,clustree,random,0.6000000000000001,2.83,16.37
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'random', 0.1]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.1 -b random -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/featureExtraction/metaAdaptiveRandomForestRegressor-s10_43_7_-1__-1_clustree_random_10.csv
# Ran cmd with result 16.35824516472158
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,43,7,-1,,-1,clustree,random,0.1,2.83,16.36
#
# Best params for featureExtraction: ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 43, 7, -1, '', '-1', 'clustree', 'random', 0.25]
# ['cep', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 25, -1, '', '-1', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 28 -m (functions.AdaGrad) -c cep -r 0.30000000000000004 -b relevance -p -1  -y -1 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/metaAdaptiveRandomForestRegressor-s10_28_25_-1__-1_clustream_relevance_30.csv
# Ran cmd with result 17.73985975145571
# Writing cep,meta.AdaptiveRandomForestRegressor -s 10,28,25,-1,,-1,clustream,relevance,0.30000000000000004,2.84,17.74
#
# ['cep', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 7, -1, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1  -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/metaAdaptiveRandomForestRegressor-s10-m80_28_7_-1__-1_clustree_relevance_25.csv
# Ran cmd with result 17.42329962800925
# Writing cep,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,7,-1,,-1,clustree,relevance,0.25,2.81,17.42
#
# ['cep', 'meta.AdaptiveRandomForestRegressor -s 10', 18, 5, 10, '', '-1', 'clustree', 'relevance', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 18 -m (functions.AdaGrad) -c cep -r 0.6000000000000001 -b relevance -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/metaAdaptiveRandomForestRegressor-s10_18_5_10__-1_clustree_relevance_60.csv
# Ran cmd with result 17.4028170995123
# ...
# Ran cmd with result 17.373668417695
# Writing cep,trees.ARFFIMTDD,65,2,10,,-1,clustream,relevance,1.0,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 2, 13, -1, '', '-1', 'clustream', 'relevance', 0.75]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 2 -m (functions.AdaGrad) -c cep -r 0.75 -b relevance -p -1  -y -1 -q clustream -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_2_13_-1__-1_clustream_relevance_75.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,2,13,-1,,-1,clustream,relevance,0.75,2.67,17.37
#
# ['cep', 'rules.AMRulesRegressor', 8, 3, 10, '', '-1', 'clustream', 'relevance', 0.5]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 8 -m (functions.AdaGrad) -c cep -r 0.5 -b relevance -p 10  -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesAMRulesRegressor_8_3_10__-1_clustream_relevance_50.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.AMRulesRegressor,8,3,10,,-1,clustream,relevance,0.5,2.67,17.37
#
# ['cep', 'rules.AMRulesRegressor', 100, 3, -1, '', '-1', 'clustream', 'relevance', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 100 -m (functions.AdaGrad) -c cep -r 0.4 -b relevance -p -1  -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesAMRulesRegressor_100_3_-1__-1_clustream_relevance_40.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.AMRulesRegressor,100,3,-1,,-1,clustream,relevance,0.4,2.67,17.37
#
# Params already ran - ['cep', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['cep', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cep', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/metaAdaptiveRandomForestRegressor-s10-m80_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.38853402908177
# Writing cep,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,13,10,,-1,clustree,random,0.25,2.86,17.39
#
# ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,10,,-1,clustree,random,0.25,2.67,17.37
#
# Params already ran - ['cep', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cep', 'trees.ARFFIMTDD', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/treesARFFIMTDD_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,trees.ARFFIMTDD,5,13,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'functions.AdaGrad', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/functionsAdaGrad_5_13_10__-1_clustree_random_25.csv
# Ran cmd with result 27.479439131542232
# Writing cep,functions.AdaGrad,5,13,10,,-1,clustree,random,0.25,12.34,27.48
#
# ['cep', 'rules.functions.TargetMean', 1, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 1 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_1_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,1,13,10,,-1,clustree,random,0.25,2.67,17.37
#
# Params already ran - ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cep', 'rules.functions.TargetMean', 28, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_28_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,28,13,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 43, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 43 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_43_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,43,13,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 18, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 18 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_18_13_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,18,13,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 5, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_5_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,5,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 3, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_3_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,3,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 1, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_1_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,1,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 25, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_25_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,25,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 4, 10, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustree -x 4) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_4_10__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,4,10,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 13, -1, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p -1  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_-1__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,-1,,-1,clustree,random,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 13, 9, '', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 9  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_9__-1_clustree_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,9,,-1,clustree,random,0.25,2.67,17.37
#
# Params already ran - ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustream', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p 10  -y -1 -q clustream -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_10__-1_clustream_random_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,10,,-1,clustream,random,0.25,2.67,17.37
#
# Params already ran - ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]
# ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_10__-1_clustree_relevance_25.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,10,,-1,clustree,relevance,0.25,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.55]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.55 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_10__-1_clustree_random_55.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,10,,-1,clustree,random,0.55,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.15000000000000002]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.15000000000000002 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_10__-1_clustree_random_15.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,10,,-1,clustree,random,0.15000000000000002,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.4 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_10__-1_clustree_random_40.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,10,,-1,clustree,random,0.4,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.6000000000000001 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_10__-1_clustree_random_60.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,10,,-1,clustree,random,0.6000000000000001,2.67,17.37
#
# ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.1]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.1 -b random -p 10  -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/airlines.arff) -i 50 -f 1 -d runs/tuning/20210831_test/airlines/cep/rulesfunctionsTargetMean_5_13_10__-1_clustree_random_10.csv
# Ran cmd with result 17.373668417695
# Writing cep,rules.functions.TargetMean,5,13,10,,-1,clustree,random,0.1,2.67,17.37
#
# Best params for cep: ['cep', 'rules.functions.TargetMean', 5, 13, 10, '', '-1', 'clustree', 'random', 0.25]

# %%
runner = ExperimentRunner('vavel_sup_slim')
runner.run()
# Out:
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/metaAdaptiveRandomForestRegressor-s10_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 76.11452689663484
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,9.91,76.11
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_7_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 79.99190063648012
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,9.57,79.99
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 18, 5, 14, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustree', 'relevance', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 18 -m (functions.AdaGrad) -c cluster -r 0.6000000000000001 -b relevance -p 14 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/metaAdaptiveRandomForestRegressor-s10_18_5_14_0,5,7,9_1,2,3,4,6,8,11,12_clustree_relevance_60.csv
# Ran cmd with result 77.03659532114571
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10,18,5,14,0,5,7,9,1,2,3,4,6,8,11,12,clustree,relevance,0.6000000000000001,9.86,77.04
#
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 5 -m (functions.AdaGrad) -c cluster -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/metaAdaptiveRandomForestRegressor-s10_5_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 78.6371279353655
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10,5,13,14,0,5,7,9,-1,clustree,random,0.25,10.06,78.64
#
# ['cluster', 'functions.AdaGrad', 43, 7, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.15000000000000002]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 43 -m (functions.AdaGrad) -c cluster -r 0.15000000000000002 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/functionsAdaGrad_43_7_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_15.csv
# Ran cmd with result 4274811.922987323
# Writing cluster,functions.AdaGrad,43,7,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.15000000000000002,5326640.64,4274811.92
#
# ['cluster', 'trees.ARFFIMTDD', 43, 3, -1, '0,5,7,9', '4,8', 'clustree', 'random', 0.8]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 43 -m (functions.AdaGrad) -c cluster -r 0.8 -b random -p -1 -t 0,5,7,9 -y 4,8 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/treesARFFIMTDD_43_3_-1_0,5,7,9_4,8_clustree_random_80.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,trees.ARFFIMTDD,43,3,-1,0,5,7,9,4,8,clustree,random,0.8,8.65,78.39
#
# ['cluster', 'trees.ARFFIMTDD', 65, 2, 14, '0,5,7,9', '4,8', 'clustream', 'relevance', 1.0]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 65 -m (functions.AdaGrad) -c cluster -r 1.0 -b relevance -p 14 -t 0,5,7,9 -y 4,8 -q clustream -x 2) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/treesARFFIMTDD_65_2_14_0,5,7,9_4,8_clustream_relevance_100.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,trees.ARFFIMTDD,65,2,14,0,5,7,9,4,8,clustream,relevance,1.0,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 2, 13, -1, '0,5,7,9', '4,8,12', 'clustream', 'relevance', 0.75]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 2 -m (functions.AdaGrad) -c cluster -r 0.75 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustream -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_2_13_-1_0,5,7,9_4,8,12_clustream_relevance_75.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,2,13,-1,0,5,7,9,4,8,12,clustream,relevance,0.75,8.65,78.39
#
# ['cluster', 'rules.AMRulesRegressor', 8, 3, 14, '0,5,7,9', '-1', 'clustream', 'relevance', 0.5]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 8 -m (functions.AdaGrad) -c cluster -r 0.5 -b relevance -p 14 -t 0,5,7,9 -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesAMRulesRegressor_8_3_14_0,5,7,9_-1_clustream_relevance_50.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.AMRulesRegressor,8,3,14,0,5,7,9,-1,clustream,relevance,0.5,8.65,78.39
#
# ['cluster', 'rules.AMRulesRegressor', 100, 3, -1, '0,5,7,9', '4,8,12', 'clustream', 'relevance', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 100 -m (functions.AdaGrad) -c cluster -r 0.4 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesAMRulesRegressor_100_3_-1_0,5,7,9_4,8,12_clustream_relevance_40.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.AMRulesRegressor,100,3,-1,0,5,7,9,4,8,12,clustream,relevance,0.4,8.65,78.39
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/metaAdaptiveRandomForestRegressor-s10-m80_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.54812555805803
# Writing cluster,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,9.85,78.55
#
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# Params already ran - ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['cluster', 'trees.ARFFIMTDD', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/treesARFFIMTDD_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,trees.ARFFIMTDD,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# ['cluster', 'functions.AdaGrad', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/functionsAdaGrad_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 4274811.908770038
# Writing cluster,functions.AdaGrad,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,5326640.65,4274811.91
#
# ['cluster', 'rules.functions.TargetMean', 1, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 1 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_1_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,1,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 5, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_5_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,5,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# Params already ran - ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['cluster', 'rules.functions.TargetMean', 43, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 43 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_43_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,43,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 18, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 18 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_18_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,18,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 5, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_5_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,5,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 3, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_3_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,3,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 1, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_1_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,1,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# Params already ran - ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['cluster', 'rules.functions.TargetMean', 28, 4, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 4) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_4_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,4,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# Params already ran - ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['cluster', 'rules.functions.TargetMean', 28, 25, 13, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p 13 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_13_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,13,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 25, 14, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p 14 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_14_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,14,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# Params already ran - ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '-1', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y -1 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_-1_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,-1,clustream,relevance,0.30000000000000004,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '4,8', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 4,8 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_4,8_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,4,8,clustream,relevance,0.30000000000000004,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '4,8,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_4,8,12_clustream_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,4,8,12,clustream,relevance,0.30000000000000004,8.65,78.39
#
# Params already ran - ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustree', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustree_relevance_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustree,relevance,0.30000000000000004,8.65,78.39
#
# Params already ran - ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'random', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b random -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_random_30.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,random,0.30000000000000004,8.65,78.39
#
# Params already ran - ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.55]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.55 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_55.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.55,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.15000000000000002]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.15000000000000002 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_15.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.15000000000000002,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.4 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_40.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.4,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.6000000000000001 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_60.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.6000000000000001,8.65,78.39
#
# ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.1]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cluster -r 0.1 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cluster/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_10.csv
# Ran cmd with result 78.3904616327173
# Writing cluster,rules.functions.TargetMean,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.1,8.65,78.39
#
# Best params for cluster: ['cluster', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 25, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.30000000000000004 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10_28_25_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_30.csv
# Ran cmd with result 79.73847064957683
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,28,25,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.30000000000000004,8.55,79.74
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_28_7_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.494594413054
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,10.02,78.49
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 18, 5, 14, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustree', 'relevance', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 18 -m (functions.AdaGrad) -c featureExtraction -r 0.6000000000000001 -b relevance -p 14 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10_18_5_14_0,5,7,9_1,2,3,4,6,8,11,12_clustree_relevance_60.csv
# Ran cmd with result 79.05326127253863
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,18,5,14,0,5,7,9,1,2,3,4,6,8,11,12,clustree,relevance,0.6000000000000001,9.29,79.05
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10_5_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.11965351359459
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10,5,13,14,0,5,7,9,-1,clustree,random,0.25,9.73,77.12
#
# ['featureExtraction', 'functions.AdaGrad', 43, 7, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustream', 'relevance', 0.15000000000000002]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.15000000000000002 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustream -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/functionsAdaGrad_43_7_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustream_relevance_15.csv
# Ran cmd with result 4274812.002810556
# Writing featureExtraction,functions.AdaGrad,43,7,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustream,relevance,0.15000000000000002,5326640.60,4274812.00
#
# ['featureExtraction', 'trees.ARFFIMTDD', 43, 3, -1, '0,5,7,9', '4,8', 'clustree', 'random', 0.8]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.8 -b random -p -1 -t 0,5,7,9 -y 4,8 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/treesARFFIMTDD_43_3_-1_0,5,7,9_4,8_clustree_random_80.csv
# Ran cmd with result 78.3904616327173
# Writing featureExtraction,trees.ARFFIMTDD,43,3,-1,0,5,7,9,4,8,clustree,random,0.8,8.65,78.39
#
# ['featureExtraction', 'trees.ARFFIMTDD', 65, 2, 14, '0,5,7,9', '4,8', 'clustream', 'relevance', 1.0]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 65 -m (functions.AdaGrad) -c featureExtraction -r 1.0 -b relevance -p 14 -t 0,5,7,9 -y 4,8 -q clustream -x 2) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/treesARFFIMTDD_65_2_14_0,5,7,9_4,8_clustream_relevance_100.csv
# Ran cmd with result 78.3904616327173
# Writing featureExtraction,trees.ARFFIMTDD,65,2,14,0,5,7,9,4,8,clustream,relevance,1.0,8.65,78.39
#
# ['featureExtraction', 'rules.functions.TargetMean', 2, 13, -1, '0,5,7,9', '4,8,12', 'clustream', 'relevance', 0.75]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 2 -m (functions.AdaGrad) -c featureExtraction -r 0.75 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustream -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/rulesfunctionsTargetMean_2_13_-1_0,5,7,9_4,8,12_clustream_relevance_75.csv
# Ran cmd with result 78.3904616327173
# Writing featureExtraction,rules.functions.TargetMean,2,13,-1,0,5,7,9,4,8,12,clustream,relevance,0.75,8.65,78.39
#
# ['featureExtraction', 'rules.AMRulesRegressor', 8, 3, 14, '0,5,7,9', '-1', 'clustream', 'relevance', 0.5]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 8 -m (functions.AdaGrad) -c featureExtraction -r 0.5 -b relevance -p 14 -t 0,5,7,9 -y -1 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/rulesAMRulesRegressor_8_3_14_0,5,7,9_-1_clustream_relevance_50.csv
# Ran cmd with result 78.3904616327173
# Writing featureExtraction,rules.AMRulesRegressor,8,3,14,0,5,7,9,-1,clustream,relevance,0.5,8.65,78.39
#
# ['featureExtraction', 'rules.AMRulesRegressor', 100, 3, -1, '0,5,7,9', '4,8,12', 'clustream', 'relevance', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.AMRulesRegressor) -n 100 -m (functions.AdaGrad) -c featureExtraction -r 0.4 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustream -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/rulesAMRulesRegressor_100_3_-1_0,5,7,9_4,8,12_clustream_relevance_40.csv
# Ran cmd with result 78.3904616327173
# Writing featureExtraction,rules.AMRulesRegressor,100,3,-1,0,5,7,9,4,8,12,clustream,relevance,0.4,8.65,78.39
#
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.51795837666872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,13,14,0,5,7,9,-1,clustree,random,0.25,8.92,77.52
#
# ['featureExtraction', 'rules.functions.TargetMean', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/rulesfunctionsTargetMean_5_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 78.3904616327173
# Writing featureExtraction,rules.functions.TargetMean,5,13,14,0,5,7,9,-1,clustree,random,0.25,8.65,78.39
#
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# ['featureExtraction', 'trees.ARFFIMTDD', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/treesARFFIMTDD_5_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 78.3904616327173
# Writing featureExtraction,trees.ARFFIMTDD,5,13,14,0,5,7,9,-1,clustree,random,0.25,8.65,78.39
#
# ['featureExtraction', 'functions.AdaGrad', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/functionsAdaGrad_5_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 4274811.915015688
# Writing featureExtraction,functions.AdaGrad,5,13,14,0,5,7,9,-1,clustree,random,0.25,5326640.64,4274811.92
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 1, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 1 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_1_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 78.60165939943286
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,1,13,14,0,5,7,9,-1,clustree,random,0.25,10.10,78.60
#
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 28, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 28 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_28_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 78.28525484933263
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,28,13,14,0,5,7,9,-1,clustree,random,0.25,10.24,78.29
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 43, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 43 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_43_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.54687516801117
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,43,13,14,0,5,7,9,-1,clustree,random,0.25,9.76,77.55
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 18, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 18 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_18_13_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 78.54515166049934
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,18,13,14,0,5,7,9,-1,clustree,random,0.25,9.86,78.55
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 5, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_5_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.51795837666872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,5,14,0,5,7,9,-1,clustree,random,0.25,8.92,77.52
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 3, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_3_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.51795837666872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,3,14,0,5,7,9,-1,clustree,random,0.25,8.92,77.52
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 1, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_1_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.51795837666872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,1,14,0,5,7,9,-1,clustree,random,0.25,8.92,77.52
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 25, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_25_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.51795837666872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,25,14,0,5,7,9,-1,clustree,random,0.25,8.92,77.52
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 4, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 4) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_4_14_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.51795837666872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,4,14,0,5,7,9,-1,clustree,random,0.25,8.92,77.52
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, -1, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p -1 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_13_-1_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.51795837666872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,13,-1,0,5,7,9,-1,clustree,random,0.25,8.92,77.52
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 13, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 13 -t 0,5,7,9 -y -1 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_13_13_0,5,7,9_-1_clustree_random_25.csv
# Ran cmd with result 77.8833887032872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,13,13,0,5,7,9,-1,clustree,random,0.25,8.94,77.88
#
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# Params already ran - ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 14, '0,5,7,9', '-1', 'clustree', 'random', 0.25]
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 14, '0,5,7,9', '4,8', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y 4,8 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_13_14_0,5,7,9_4,8_clustree_random_25.csv
# Ran cmd with result 77.51795837666872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,13,14,0,5,7,9,4,8,clustree,random,0.25,8.92,77.52
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 14, '0,5,7,9', '4,8,12', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10 -m 80) -n 5 -m (functions.AdaGrad) -c featureExtraction -r 0.25 -b random -p 14 -t 0,5,7,9 -y 4,8,12 -q clustree -x 13) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/featureExtraction/metaAdaptiveRandomForestRegressor-s10-m80_5_13_14_0,5,7,9_4,8,12_clustree_random_25.csv
# Ran cmd with result 77.51795837666872
# Writing featureExtraction,meta.AdaptiveRandomForestRegressor -s 10 -m 80,5,13,14,0,5,7,9,4,8,12,clustree,random,0.25,8.92,77.52
#
# ['featureExtraction', 'meta.AdaptiveRandomForestRegressor -s 10 -m 80', 5, 13, 14, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustree', 'random', 0.25]
# ...
#
# ['cep', 'trees.ARFFIMTDD', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (trees.ARFFIMTDD) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/treesARFFIMTDD_28_7_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,trees.ARFFIMTDD,28,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'functions.AdaGrad', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (functions.AdaGrad) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/functionsAdaGrad_28_7_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 4274811.906938487
# Writing cep,functions.AdaGrad,28,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,5326640.65,4274811.91
#
# ['cep', 'rules.functions.TargetMean', 1, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 1 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_1_7_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,1,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 5, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 5 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_5_7_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,5,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# Params already ran - ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# ['cep', 'rules.functions.TargetMean', 43, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 43 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_43_7_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,43,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 18, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 18 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_18_7_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,18,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 5, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 5) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_5_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,5,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 3, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 3) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_3_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,3,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 1, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 1) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_1_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,1,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 25, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_25_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,25,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 4, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 4) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_4_-1_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,4,-1,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# Params already ran - ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# ['cep', 'rules.functions.TargetMean', 28, 7, 13, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p 13 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_13_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,13,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 7, 14, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p 14 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_14_0,5,7,9_4,8,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,14,0,5,7,9,4,8,12,clustree,relevance,0.25,8.65,78.39
#
# Params already ran - ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '-1', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y -1 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_-1_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,-1,clustree,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_4,8_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,4,8,clustree,relevance,0.25,8.65,78.39
#
# Params already ran - ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '1,2,3,4,6,8,11,12', 'clustree', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 1,2,3,4,6,8,11,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_1,2,3,4,6,8,11,12_clustree_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,1,2,3,4,6,8,11,12,clustree,relevance,0.25,8.65,78.39
#
# Params already ran - ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustream', 'relevance', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustream -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_4,8,12_clustream_relevance_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,4,8,12,clustream,relevance,0.25,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'random', 0.25]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.25 -b random -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_4,8,12_clustree_random_25.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,4,8,12,clustree,random,0.25,8.65,78.39
#
# Params already ran - ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.55]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.55 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_4,8,12_clustree_relevance_55.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.55,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.15000000000000002]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.15000000000000002 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_4,8,12_clustree_relevance_15.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.15000000000000002,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.4]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.4 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_4,8,12_clustree_relevance_40.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.4,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.6000000000000001]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.6000000000000001 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_4,8,12_clustree_relevance_60.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.6000000000000001,8.65,78.39
#
# ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.1]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (rules.functions.TargetMean) -n 28 -m (functions.AdaGrad) -c cep -r 0.1 -b relevance -p -1 -t 0,5,7,9 -y 4,8,12 -q clustree -x 7) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 50 -f 1 -d runs/tuning/20210831_test/vavel_sup_slim/cep/rulesfunctionsTargetMean_28_7_-1_0,5,7,9_4,8,12_clustree_relevance_10.csv
# Ran cmd with result 78.3904616327173
# Writing cep,rules.functions.TargetMean,28,7,-1,0,5,7,9,4,8,12,clustree,relevance,0.1,8.65,78.39
#
# Best params for cep: ['cep', 'rules.functions.TargetMean', 28, 7, -1, '0,5,7,9', '4,8,12', 'clustree', 'relevance', 0.25]

# %%
runner = ExperimentRunner('vavel')
runner.run()
# Out:
# ['cluster', 'meta.AdaptiveRandomForestRegressor -s 10', 28, 25, -1, '2,8,17,18,23', '3,4,5,6,16,22,26,29', 'clustream', 'relevance', 0.30000000000000004]
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -s 10) -n 28 -m (functions.AdaGrad) -c cluster -r 0.30000000000000004 -b relevance -p -1 -t 2,8,17,18,23 -y 3,4,5,6,16,22,26,29 -q clustream -x 25) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_90500.arff) -i 5000 -f 100 -d runs/tuning/20210831_test/vavel/cluster/metaAdaptiveRandomForestRegressor-s10_28_25_-1_2,8,17,18,23_3,4,5,6,16,22,26,29_clustream_relevance_30.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\kosma\desktop\magister\featextream\venv\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1426         try:
# -> 1427             x = float(x)
#    1428         except ValueError:
#
# ValueError: could not convert string to float: '??????????????????????????????????????????????????mean absolute error??????????????????????????????????????????????????'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\users\kosma\desktop\magister\featextream\venv\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1430             try:
# -> 1431                 x = complex(x)
#    1432             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-e748f893bc48> in <module>
#       1 runner = ExperimentRunner('vavel')
# ----> 2 runner.run()
#
# <ipython-input-26-40394470db8d> in run(self)
#     114                 rs
#     115             ]
# --> 116             initial_params = random_search(self.run_and_get_value, hyperparams_base[ex], 10)
#     117             best_params = greedy_search(self.run_and_get_value, hyperparams_base[ex], initial_params, 5)
#     118             print(f"Best params for {ex}: "  + str(best_params))
#
# <ipython-input-2-f0623cf752d1> in random_search(f, hyperparameters, tries, set_seed)
#       6     for i in range(0, tries):
#       7         random_params = choose_random_hyperparameters(hyperparameters)
# ----> 8         result = f(random_params)
#       9         if  best_result is None or result > best_result:
#      10             best_params = random_params
#
# <ipython-input-26-40394470db8d> in run_and_get_value(self, params)
#      89         result_df = pd.read_csv(target_file, sep = ',')
#      90         col_name = 'classifications correct (percent)' if self.exp_args['classification'] else 'mean absolute error'
# ---> 91         result = np.mean(result_df[col_name])
#      92         print (f"Ran cmd with result {result}")
#      93         run_result_file = target_file.rsplit( "/", 1 )[0] + "/_run_result.csv"
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# c:\users\kosma\desktop\magister\featextream\venv\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3415             pass
#    3416         else:
# -> 3417             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3418
#    3419     return _methods._mean(a, axis=axis, dtype=dtype,
#
# c:\users\kosma\desktop\magister\featextream\venv\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11473             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11474         return self._reduce(
# > 11475             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11476         )
#   11477
#
# c:\users\kosma\desktop\magister\featextream\venv\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4247                 )
#    4248             with np.errstate(all="ignore"):
# -> 4249                 return op(delegate, skipna=skipna, **kwds)
#    4250
#    4251     def _reindex_indexer(self, new_index, indexer, copy):
#
# c:\users\kosma\desktop\magister\featextream\venv\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# c:\users\kosma\desktop\magister\featextream\venv\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# c:\users\kosma\desktop\magister\featextream\venv\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     561         dtype_count = dtype
#     562     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 563     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     564
#     565     if axis is not None and getattr(the_sum, "ndim", False):
#
# c:\users\kosma\desktop\magister\featextream\venv\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1432             except ValueError as err:
#    1433                 # e.g. "foo"
# -> 1434                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1435     return x
#    1436
#
# TypeError: Could not convert ??????????????????????????????????????????????????mean absolute error?????????????????????????????????????????????????? to numeric

# %%
reg_buffer_learners = [
    'rules.functions.TargetMean',
    'rules.functions.FadingTargetMean',
    'functions.AdaGrad',
    'meta.AdaptiveRandomForestRegressor -s 10',
    'meta.AdaptiveRandomForestRegressor -s 10 -m 80',
    'rules.AMRulesRegressor',
    'rules.functions.Perceptron',
    'trees.ARFFIMTDD',

]

clf_buffer_learners = [
    'functions.MajorityClass',
    'functions.NoChange',
    'lazy.SAMkNN',
    'bayes.NaiveBayes',
    'meta.AdaptiveRandomForest -s 10',
    'meta.AdaptiveRandomForest -s 10 -m 80',
    'trees.HoeffdingAdaptiveTree',
    'meta.OzaBagAdwin',
]

if str(params) in self.ran_params:
    print("Params already ran - " + str(params))
    return float('-inf')
self.ran_params.append(str(params))
print(params)
self.index += 1
max_together = 1
cmd, target_file = self.generate_command(params[0], params[1], params[2], params[3], params[4], 
                       params[5], params[6], params[7], params[8], params[9], target_dir = '20210831_test')
print(f"Running cmd = {cmd}")
out = self.run_command(cmd,f'{self.dataset}{self.index}')
self.outs.append(out)

if len(self.outs) >= max_together:
    self.outs[len(self.outs) - max_together].communicate()

result_df = pd.read_csv(target_file, sep = ',')
col_name = 'classifications correct (percent)' if self.exp_args['classification'] else 'mean absolute error'
result = np.mean(result_df[col_name])
print (f"Ran cmd with result {result}")
run_result_file = target_file.rsplit( "/", 1 )[0] + "/_run_result.csv"
with open(run_result_file, 'a') as file:
    stdev =  np.std(result_df[col_name])
    to_write = ",".join([str(p) for p in params]) + "," + "{:.2f}".format(stdev) + "," + "{:.2f}".format(result) + "\n"
    print("Writing " + to_write)
    file.write(to_write)
return result if self.exp_args['classification']  else -result

std_set = r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff'
slim_set = r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff'


std_learn = [f'EvaluatePrequentialRegression -l ({l}) -s (ArffFileStream -f {std_set} ) -i 32000 -f 1000 -q 1000 -d runs/tuning/{l.replace(" ","")}' for l in learners]
slim_learn = [f'EvaluatePrequentialRegression -l ({l}) -s (ArffFileStream -f {slim_set} ) -i 32000 -f 1000 -q 1000 -d runs/tuning/slim_{l.replace(" ","")}' for l in learners]

# %%
file =  r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff'
task = 'EvaluatePrequentialRegression'
learner = 'BufferLearner'
arf_k = 14
# buffer_learner = f'(meta.AdaptiveRandomForestRegressor -l (ARFFIMTDD -k {arf_k} -s VarianceReductionSplitCriterion -g 50 -c 0.01) -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'

relevance_learner = '(meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'
buffer_learner = f'(meta.AdaptiveRandomForestRegressor -l (ARFFIMTDD -k {arf_k} -s VarianceReductionSplitCriterion -g 50 -c 0.01) -m 80 -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'
stream = f'(ArffFileStream -f {file})'

id_index = 15

i = 32000
f = 1000
q = 1000
def generate_command(n, extractor, partition_id, time_ids, cluster_num, buffer_ids, cluster_type='clustree', buffer_type = 'random', r = 1, target_dir = ''):
    pathlib.Path(f'runs/tuning/{target_dir}').mkdir(parents=True, exist_ok=True)
    
    target_file = f'runs/tuning/{target_dir}vavel_slim_{extractor}_{n}_{cluster_num}_{partition_id}_{time_ids}_{buffer_ids}_{cluster_type}_{buffer_type}_{int(r*100)}.csv'
    start_cmd = f'{task} -l ({learner} -l {buffer_learner} -n {n} -m {relevance_learner}'
    end_cmd = f') -s {stream} -i {i} -f {f} -q {q} -d {target_file}'
    cmd = f'{start_cmd} -c {extractor} -r {r} -b {buffer_type} -p {partition_id} -t {time_ids} -y {buffer_ids} -q {cluster_type} -x {cluster_num}{end_cmd}'
    cmd = cmd.replace("\\","/")
    return cmd

# %%
buffer_sizes = [1,5,10,25,50,100]
cluster_num = [2,3,4,5,8,25]
extractor = ['naive','cluster','featureExtraction', 'cep']
vavel_slim_partition_id = [13, 14]
time_ids = '0,5,7,9'
buffer_ids = ['-1', '4,8', '4,8,12', '1,2,3,4,6,8,11,12']
cluster_types = ['clustree', 'clustream']

buffer_types = ['random', 'relevance']
rs = [0.1, 0.25, 0.5]

# %%
def run_command(cmd, file_suffix):
    file_contents = f'@echo off\n\
    \n\
    set BASEDIR=%~dp0\..\n\
    set MEMORY=6g\n\
    \n\
    java -Xmx%MEMORY% -cp "%BASEDIR%/lib/*" -javaagent:"%BASEDIR%/lib/sizeofag-1.0.4.jar" ^\n\
    moa.DoTask ^\n\
    "{cmd} "'
    filename = r'..\moa-release-2020.07.1\bin\moa_test_run_' + file_suffix + '.bat'
    with open(filename, 'w') as file:
        file.write(file_contents)
    out = subprocess.Popen(filename)
    return out

# %%
outs = []
max_together = 2

# %%
outs = []
for n in buffer_sizes:
    cmd = generate_command(n, 'cluster', 14, time_ids, 8, '-1', target_dir = '20210829/cluster/n/')
    print(f"Running with n = {n}")
    print(f"Running cmd = {cmd}")
    out = run_command(cmd,f'n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 1
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -l (ARFFIMTDD -k 14 -s VarianceReductionSplitCriterion -g 50 -c 0.01) -m 80 -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -n 1 -m (meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -c cluster -r 1 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 8) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 32000 -f 1000 -q 1000 -d runs/tuning/20210829/cluster/n/vavel_slim_cluster_1_8_14_0,5,7,9_-1_clustree_random_100.csv
# Running with n = 5
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -l (ARFFIMTDD -k 14 -s VarianceReductionSplitCriterion -g 50 -c 0.01) -m 80 -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -n 5 -m (meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -c cluster -r 1 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 8) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 32000 -f 1000 -q 1000 -d runs/tuning/20210829/cluster/n/vavel_slim_cluster_5_8_14_0,5,7,9_-1_clustree_random_100.csv
# Running with n = 10
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -l (ARFFIMTDD -k 14 -s VarianceReductionSplitCriterion -g 50 -c 0.01) -m 80 -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -n 10 -m (meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -c cluster -r 1 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 8) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 32000 -f 1000 -q 1000 -d runs/tuning/20210829/cluster/n/vavel_slim_cluster_10_8_14_0,5,7,9_-1_clustree_random_100.csv
# Running with n = 25
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -l (ARFFIMTDD -k 14 -s VarianceReductionSplitCriterion -g 50 -c 0.01) -m 80 -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -n 25 -m (meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -c cluster -r 1 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 8) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 32000 -f 1000 -q 1000 -d runs/tuning/20210829/cluster/n/vavel_slim_cluster_25_8_14_0,5,7,9_-1_clustree_random_100.csv
# Running with n = 50
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -l (ARFFIMTDD -k 14 -s VarianceReductionSplitCriterion -g 50 -c 0.01) -m 80 -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -n 50 -m (meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -c cluster -r 1 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 8) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 32000 -f 1000 -q 1000 -d runs/tuning/20210829/cluster/n/vavel_slim_cluster_50_8_14_0,5,7,9_-1_clustree_random_100.csv
# Running with n = 100
# Running cmd = EvaluatePrequentialRegression -l (BufferLearner -l (meta.AdaptiveRandomForestRegressor -l (ARFFIMTDD -k 14 -s VarianceReductionSplitCriterion -g 50 -c 0.01) -m 80 -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -n 100 -m (meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -c cluster -r 1 -b random -p 14 -t 0,5,7,9 -y -1 -q clustree -x 8) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/result_sup_slim.arff) -i 32000 -f 1000 -q 1000 -d runs/tuning/20210829/cluster/n/vavel_slim_cluster_100_8_14_0,5,7,9_-1_clustree_random_100.csv

# %%
for n in [1,3,5,10]:
    cmd = generate_command(n, 'naive', 14, time_ids, 25, '4,8,12', target_dir = '20210613/naive/n/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'naive_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 1
# Running with n = 3
# Running with n = 5
# Running with n = 10

# %%
for n in buffer_sizes[1:]:
    cmd = generate_command(n, 'cep', 14, time_ids, 6, '-1', target_dir = '20210613/cep/n/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'cep_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 5
# Running with n = 10
# Running with n = 25
# Running with n = 50
# Running with n = 100

# %%
for n in [1,3,5,10,25]:
    cmd = generate_command(n, 'featureExtraction', 14, time_ids, 25, '-1', target_dir = '20210613/extract/n/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'extract_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 1
# Running with n = 3
# Running with n = 5
# Running with n = 10
# Running with n = 25

# %%
for n in [5,10,25]:
    cmd = generate_command(n, 'featureExtraction', 14, time_ids, 25, '-1', target_dir = '20210613/extract/n/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'extract_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()

# %%
for c in cluster_num:
    if c != 8:
        cmd = generate_command(25, 'cluster', 14, time_ids, c, '-1', target_dir = '20210613/cluster/c/')
        print(f"Running with c = {c}")
        out = run_command(cmd,f'c{c}')
        outs.append(out)

        if len(outs) >= max_together:
            outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 2
# Running with c = 3
# Running with c = 4
# Running with c = 5
# Running with c = 25

# %%
for c in [10,15]:
    if c != 8:
        cmd = generate_command(25, 'cluster', 14, time_ids, c, '-1', target_dir = '20210613/cluster/c/')
        print(f"Running with c = {c}")
        out = run_command(cmd,f'c{c}')
        outs.append(out)

        if len(outs) >= max_together:
            outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 10
# Running with c = 15

# %%
clustream_num = [3,5,8,10,15,25]
for c in clustream_num:
    if c != 8:
        cmd = generate_command(25, 'cluster', 14, time_ids, c, '-1', 'clustream', target_dir = '20210613/cluster/c/')
        print(f"Running with c = {c}")
        out = run_command(cmd,f'c{c}')
        outs.append(out)

        if len(outs) >= max_together:
            outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 3
# Running with c = 5
# Running with c = 10
# Running with c = 15
# Running with c = 25

# %%
for c in [10,15]:
    cmd = generate_command(100, 'cluster', 14, time_ids, c, '-1')
    run_command(cmd,f'c{c}')

# %%
clustream_num = [3,5,8,10,15,25]

# %%
for c in clustream_num[:2]:
    cmd = generate_command(100, 'cluster', 14, time_ids, c, '-1', 'clustream')
    run_command(cmd,f'c2{c}')

# %%
for c in clustream_num[2:4]:
    cmd = generate_command(100, 'cluster', 14, time_ids, c, '-1', 'clustream')
    run_command(cmd,f'c2{c}')

# %%
for c in clustream_num[4:]:
    cmd = generate_command(100, 'cluster', 14, time_ids, c, '-1', 'clustream')
    run_command(cmd,f'c2{c}')

# %%
max_together = 2

# %%
buffer_ids
# Out:
# ['-1', '4,8', '4,8,12', '1,2,3,4,6,8,11,12']

# %%
for b in buffer_ids:
    cmd = generate_command(100, 'cluster', 14, time_ids, 25, b)
    print(f"Running with b = {b}")
    out = run_command(cmd,f'b{b.replace(",","-")}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with b = -1
# Running with b = 4,8
# Running with b = 4,8,12
# Running with b = 1,2,3,4,6,8,11,12

# %%
# Out:
# Running with n = 1
# Running with n = 3
# Running with n = 5
# Running with n = 10

# %%
# Out:
# Running with n = 5
# Running with n = 10
# Running with n = 25
# Running with n = 50
# Running with n = 100

# %%
# Out:
# Running with n = 1
# Running with n = 3
# Running with n = 5
# Running with n = 10
# Running with n = 25

# %%
for c in [3,4,8,10]:
    cmd = generate_command(25, 'cep', 14, time_ids, c, '-1')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'cep_c{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 3
# Running with c = 4
# Running with c = 8
# Running with c = 10

# %%
for c in [3,4,8,10]:
    cmd = generate_command(25, 'cep', 14, time_ids, c, '-1','clustream')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'cep_c2{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 3
# Running with c = 4
# Running with c = 8
# Running with c = 10

# %%
for c in cluster_num[:-1]:
    cmd = generate_command(25, 'featureExtraction', 14, time_ids, c, '-1')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'extract_c{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 2
# Running with c = 3
# Running with c = 4
# Running with c = 5
# Running with c = 8

# %%
for c in cluster_num:
    cmd = generate_command(25, 'featureExtraction', 14, time_ids, c, '-1', 'clustream')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'extract_c2{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 2
# Running with c = 3
# Running with c = 4
# Running with c = 5
# Running with c = 8
# Running with c = 25

# %%
for r in rs:
    cmd = generate_command(100, 'cluster', 14, time_ids, 25, '-1', r=r)
    print(f"Running with r = {r}")
    out = run_command(cmd,f'r{r}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with r = 0.1
# Running with r = 0.25
# Running with r = 0.5

# %%
for r in rs:
    cmd = generate_command(100, 'cluster', 14, time_ids, 25, '-1', buffer_type= 'relevance',r=r)
    print(f"Running with r = {r}")
    out = run_command(cmd,f'r2{r}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with r = 0.1
# Running with r = 0.25
# Running with r = 0.5

# %%
for r in rs:
    cmd = generate_command(25, 'featureExtraction', 14, time_ids, 8, '-1', 'clustream', r=r)
    print(f"Running with r = {r}")
    out = run_command(cmd,f'extract_r{r}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with r = 0.1
# Running with r = 0.25
# Running with r = 0.5

# %%
for r in rs:
    cmd = generate_command(25, 'featureExtraction', 14, time_ids, 8, '-1', 'clustream', buffer_type='relevance', r=r)
    print(f"Running with r = {r}")
    out = run_command(cmd,f'extract_r2{r}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with r = 0.1
# Running with r = 0.25
# Running with r = 0.5

# %%
for c in [6]:
    cmd = generate_command(25, 'cep', 14, time_ids, c, '-1','clustream')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'cep_c2{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 6

# %%
for r in rs:
    cmd = generate_command(25, 'cep', 14, time_ids, 6, '-1','clustream', buffer_type='relevance', r=r)
    print(f"Running with r = {r}")
    out = run_command(cmd,f'cep_r2{r}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with r = 0.1
# Running with r = 0.25
# Running with r = 0.5

# %%
for r in rs:
    cmd = generate_command(25, 'cep', 14, time_ids, 6, '-1','clustream', r=r)
    print(f"Running with r = {r}")
    out = run_command(cmd,f'cep_r{r}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with r = 0.1
# Running with r = 0.25
# Running with r = 0.5

# %%
for p in [13]:
    cmd = generate_command(100, 'cluster', p, time_ids, 25, '-1', buffer_type= 'relevance',r=0.1)
    print(f"Running with p = {p}")
    out = run_command(cmd,f'p{p}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with p = 13

# %%
for p in [13]:
    cmd = generate_command(25, 'featureExtraction', p, time_ids, 8, '-1', 'clustream', buffer_type='random', r=0.1)
    print(f"Running with p = {p}")
    out = run_command(cmd,f'extract_p{p}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with p = 13

# %%
for  p in [13]:
    cmd = generate_command(25, 'cep', 14, time_ids, 6, '-1','clustree', r=0.5)
    print(f"Running with p = {p}")
    out = run_command(cmd,f'cep_p{p}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with p = 13

# %%
with open(r'..\moa-release-2020.07.1\bin\moa_test_run.bat', 'w') as file:
    file.write(file_contents)

# %%
out = subprocess.Popen(r'..\moa-release-2020.07.1\bin\moa_test_run.bat')

# %%
file_contents = f'@echo off\n\
\n\
set BASEDIR=%~dp0\..\n\
set MEMORY=6g\n\
\n\
java -Xmx%MEMORY% -cp "%BASEDIR%/lib/*" -javaagent:"%BASEDIR%/lib/sizeofag-1.0.4.jar" ^\n\
moa.DoTask ^\n\
"{cmd} "'

# %%
learners = [
    'rules.functions.TargetMean',
    'rules.functions.FadingTargetMean',
    'functions.AdaGrad',
    'meta.AdaptiveRandomForestRegressor',
    'meta.AdaptiveRandomForestRegressor -m 80',
    'rules.AMRulesRegressor',
    'rules.functions.Perceptron',
    'trees.ARFFIMTDD',

]
std_set = r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff'
slim_set = r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff'


std_learn = [f'EvaluatePrequentialRegression -l ({l}) -s (ArffFileStream -f {std_set} ) -i 32000 -f 1000 -q 1000 -d runs/tuning/{l.replace(" ","")}' for l in learners]
slim_learn = [f'EvaluatePrequentialRegression -l ({l}) -s (ArffFileStream -f {slim_set} ) -i 32000 -f 1000 -q 1000 -d runs/tuning/slim_{l.replace(" ","")}' for l in learners]

# %%
std_learn[4:5]
# Out:
# ['EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -m 80) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/meta.AdaptiveRandomForestRegressor-m80']

# %%
index = 0
for cmd in std_learn:
    print(f"Running cmd {cmd}")
    out = run_command(cmd,f'baseline_{index}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
    index+= 1
# Out:
# Running cmd EvaluatePrequentialRegression -l (rules.functions.TargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/rules.functions.TargetMean
# Running cmd EvaluatePrequentialRegression -l (rules.functions.FadingTargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/rules.functions.FadingTargetMean
# Running cmd EvaluatePrequentialRegression -l (functions.AdaGrad) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/functions.AdaGrad
# Running cmd EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/meta.AdaptiveRandomForestRegressor
# Running cmd EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/meta.AdaptiveRandomForestRegressor -m 80
# Running cmd EvaluatePrequentialRegression -l (rules.meta.RandomAMRules) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/rules.meta.RandomAMRules
# Running cmd EvaluatePrequentialRegression -l (rules.AMRulesRegressor) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/rules.AMRulesRegressor

# %%
index = 0
for cmd in std_learn[-2:]:
    print(f"Running cmd {cmd}")
    out = run_command(cmd,f'baseline_{index}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
    index+= 1
# Out:
# Running cmd EvaluatePrequentialRegression -l (rules.functions.Perceptron) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/rules.functions.Perceptron
# Running cmd EvaluatePrequentialRegression -l (trees.ARFFIMTDD) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/trees.ARFFIMTDD

# %%
index = 0
for cmd in slim_learn:
    print(f"Running cmd {cmd}")
    out = run_command(cmd,f'baseline_{index}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
    index+= 1
# Out:
# Running cmd EvaluatePrequentialRegression -l (rules.functions.TargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/rules.functions.TargetMean
# Running cmd EvaluatePrequentialRegression -l (rules.functions.FadingTargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/rules.functions.FadingTargetMean
# Running cmd EvaluatePrequentialRegression -l (functions.AdaGrad) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/functions.AdaGrad
# Running cmd EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/meta.AdaptiveRandomForestRegressor
# Running cmd EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/meta.AdaptiveRandomForestRegressor -m 80
# Running cmd EvaluatePrequentialRegression -l (rules.AMRulesRegressor) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/rules.AMRulesRegressor
# Running cmd EvaluatePrequentialRegression -l (rules.functions.Perceptron) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/rules.functions.Perceptron
# Running cmd EvaluatePrequentialRegression -l (trees.ARFFIMTDD) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/trees.ARFFIMTDD

# %%
index = 0
for cmd in std_learn[4:5]:
    print(f"Running cmd {cmd}")
    out = run_command(cmd,f'baseline_{index}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
    index+= 1
# Out:
# Running cmd EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/meta.AdaptiveRandomForestRegressor-m80

# %%
index = 0
for cmd in slim_learn[4:5]:
    print(f"Running cmd {cmd}")
    out = run_command(cmd,f'baseline_{index}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
    index+= 1
# Out:
# Running cmd EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\result_sup_slim.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/slim_meta.AdaptiveRandomForestRegressor-m80

# %%
learners_clf = [
    'functions.MajorityClass',
    'functions.NoChange',
    'lazy.SAMkNN',
    'bayes.NaiveBayes',
    'meta.AdaptiveRandomForest',
    'meta.AdaptiveRandomForest -m 80',
    'trees.HoeffdingAdaptiveTree',
    'meta.OzaBagAdwin',

]
generated_sets = ['generators.RandomRBFGenerator', 'generators.HyperplaneGenerator','generators.LEDGenerator']

index = 0
cmds = []
for gen_set in generated_sets:
    cmds += [f'EvaluatePrequential -l ({l}) -s ({gen_set}) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/{l.replace(" ","")}_{gen_set}.csv' for l in learners_clf]

# %%
index = 0
for cmd in cmds:
    print(f"Running cmd {cmd}")
    out = run_command(cmd,f'generator_{index}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
    index+= 1
# Out:
# Running cmd EvaluatePrequential -l (functions.MajorityClass) -s (generators.RandomRBFGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/functions.MajorityClass_generators.RandomRBFGenerator.csv
# Running cmd EvaluatePrequential -l (functions.NoChange) -s (generators.RandomRBFGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/functions.NoChange_generators.RandomRBFGenerator.csv
# Running cmd EvaluatePrequential -l (lazy.SAMkNN) -s (generators.RandomRBFGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/lazy.SAMkNN_generators.RandomRBFGenerator.csv
# Running cmd EvaluatePrequential -l (bayes.NaiveBayes) -s (generators.RandomRBFGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/bayes.NaiveBayes_generators.RandomRBFGenerator.csv
# Running cmd EvaluatePrequential -l (meta.AdaptiveRandomForest) -s (generators.RandomRBFGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/meta.AdaptiveRandomForest_generators.RandomRBFGenerator.csv
# Running cmd EvaluatePrequential -l (meta.AdaptiveRandomForest -m 80) -s (generators.RandomRBFGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/meta.AdaptiveRandomForest-m80_generators.RandomRBFGenerator.csv
# Running cmd EvaluatePrequential -l (trees.HoeffdingAdaptiveTree) -s (generators.RandomRBFGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/trees.HoeffdingAdaptiveTree_generators.RandomRBFGenerator.csv
# Running cmd EvaluatePrequential -l (meta.OzaBagAdwin) -s (generators.RandomRBFGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/meta.OzaBagAdwin_generators.RandomRBFGenerator.csv
# Running cmd EvaluatePrequential -l (functions.MajorityClass) -s (generators.HyperplaneGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/functions.MajorityClass_generators.HyperplaneGenerator.csv
# Running cmd EvaluatePrequential -l (functions.NoChange) -s (generators.HyperplaneGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/functions.NoChange_generators.HyperplaneGenerator.csv
# Running cmd EvaluatePrequential -l (lazy.SAMkNN) -s (generators.HyperplaneGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/lazy.SAMkNN_generators.HyperplaneGenerator.csv
# Running cmd EvaluatePrequential -l (bayes.NaiveBayes) -s (generators.HyperplaneGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/bayes.NaiveBayes_generators.HyperplaneGenerator.csv
# Running cmd EvaluatePrequential -l (meta.AdaptiveRandomForest) -s (generators.HyperplaneGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/meta.AdaptiveRandomForest_generators.HyperplaneGenerator.csv
# Running cmd EvaluatePrequential -l (meta.AdaptiveRandomForest -m 80) -s (generators.HyperplaneGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/meta.AdaptiveRandomForest-m80_generators.HyperplaneGenerator.csv
# Running cmd EvaluatePrequential -l (trees.HoeffdingAdaptiveTree) -s (generators.HyperplaneGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/trees.HoeffdingAdaptiveTree_generators.HyperplaneGenerator.csv
# Running cmd EvaluatePrequential -l (meta.OzaBagAdwin) -s (generators.HyperplaneGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/meta.OzaBagAdwin_generators.HyperplaneGenerator.csv
# Running cmd EvaluatePrequential -l (functions.MajorityClass) -s (generators.LEDGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/functions.MajorityClass_generators.LEDGenerator.csv
# Running cmd EvaluatePrequential -l (functions.NoChange) -s (generators.LEDGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/functions.NoChange_generators.LEDGenerator.csv
# Running cmd EvaluatePrequential -l (lazy.SAMkNN) -s (generators.LEDGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/lazy.SAMkNN_generators.LEDGenerator.csv
# Running cmd EvaluatePrequential -l (bayes.NaiveBayes) -s (generators.LEDGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/bayes.NaiveBayes_generators.LEDGenerator.csv
# Running cmd EvaluatePrequential -l (meta.AdaptiveRandomForest) -s (generators.LEDGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/meta.AdaptiveRandomForest_generators.LEDGenerator.csv
# Running cmd EvaluatePrequential -l (meta.AdaptiveRandomForest -m 80) -s (generators.LEDGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/meta.AdaptiveRandomForest-m80_generators.LEDGenerator.csv
# Running cmd EvaluatePrequential -l (trees.HoeffdingAdaptiveTree) -s (generators.LEDGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/trees.HoeffdingAdaptiveTree_generators.LEDGenerator.csv
# Running cmd EvaluatePrequential -l (meta.OzaBagAdwin) -s (generators.LEDGenerator) -i 50000 -f 1000 -q 1000 -d runs/tuning/generator2/meta.OzaBagAdwin_generators.LEDGenerator.csv

# %%
learners_clf = [
    'functions.MajorityClass',
    'functions.NoChange',
    'lazy.SAMkNN',
    'bayes.NaiveBayes',
    'meta.AdaptiveRandomForest',
    'meta.AdaptiveRandomForest -m 80',
    'trees.HoeffdingAdaptiveTree',
    'meta.OzaBagAdwin',

]
rest_sets = ['WISDM', 'electricity_arff']

index = 0
cmds = []
wisdm_fullpath =  f'C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\{rest_sets[0]}.arff'
electricity_fullpath =  f'C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\{rest_sets[1]}.arff'
cmds += [f'EvaluatePrequential -l ({l}) -s (ArffFileStream -f {wisdm_fullpath})-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/{l.replace(" ","")}_wisdm.csv' for l in learners_clf]
# cmds += [f'EvaluatePrequential -l ({l}) -s (ArffFileStream -f {electricity_fullpath}) -i 45000 -f 1000 -q 1000 -d runs/tuning/wisdm/{l.replace(" ","")}_electricity.csv' for l in learners_clf]

# %%
cmds
# Out:
# ['EvaluatePrequential -l (functions.MajorityClass) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/functions.MajorityClass_wisdm.csv',
#  'EvaluatePrequential -l (functions.NoChange) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/functions.NoChange_wisdm.csv',
#  'EvaluatePrequential -l (lazy.SAMkNN) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/lazy.SAMkNN_wisdm.csv',
#  'EvaluatePrequential -l (bayes.NaiveBayes) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/bayes.NaiveBayes_wisdm.csv',
#  'EvaluatePrequential -l (meta.AdaptiveRandomForest) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/meta.AdaptiveRandomForest_wisdm.csv',
#  'EvaluatePrequential -l (meta.AdaptiveRandomForest -m 80) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/meta.AdaptiveRandomForest-m80_wisdm.csv',
#  'EvaluatePrequential -l (trees.HoeffdingAdaptiveTree) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/trees.HoeffdingAdaptiveTree_wisdm.csv',
#  'EvaluatePrequential -l (meta.OzaBagAdwin) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/meta.OzaBagAdwin_wisdm.csv']

# %%
max_together = 10
index = 0
for cmd in cmds:
    print(f"Running cmd {cmd}")
    out = run_command(cmd,f'generator_{index}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
    index+= 1
# Out:
# Running cmd EvaluatePrequential -l (functions.MajorityClass) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/functions.MajorityClass_wisdm.csv
# Running cmd EvaluatePrequential -l (functions.NoChange) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/functions.NoChange_wisdm.csv
# Running cmd EvaluatePrequential -l (lazy.SAMkNN) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/lazy.SAMkNN_wisdm.csv
# Running cmd EvaluatePrequential -l (bayes.NaiveBayes) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/bayes.NaiveBayes_wisdm.csv
# Running cmd EvaluatePrequential -l (meta.AdaptiveRandomForest) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/meta.AdaptiveRandomForest_wisdm.csv
# Running cmd EvaluatePrequential -l (meta.AdaptiveRandomForest -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/meta.AdaptiveRandomForest-m80_wisdm.csv
# Running cmd EvaluatePrequential -l (trees.HoeffdingAdaptiveTree) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/trees.HoeffdingAdaptiveTree_wisdm.csv
# Running cmd EvaluatePrequential -l (meta.OzaBagAdwin) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\WISDM.arff)-e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/meta.OzaBagAdwin_wisdm.csv

# %%
learners = [
    'rules.functions.TargetMean',
    'rules.functions.FadingTargetMean',
    'functions.AdaGrad',
    'meta.AdaptiveRandomForestRegressor',
    'meta.AdaptiveRandomForestRegressor -m 80',
    'rules.AMRulesRegressor',
    'rules.functions.Perceptron',
    'trees.ARFFIMTDD',

]
air_set = r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff'


air_learn = [f'EvaluatePrequentialRegression -l ({l}) -s (ArffFileStream -f {air_set} ) -i 50000 -f 500 -q 500 -d runs/tuning/airlines/{l.replace(" ","")}' for l in learners]

# %%
index = 0
max_together = 3
for cmd in air_learn:
    print(f"Running cmd {cmd}")
    out = run_command(cmd,f'baseline_{index}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
    index+= 1
# Out:
# Running cmd EvaluatePrequentialRegression -l (rules.functions.TargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/airlines/rules.functions.TargetMean
# Running cmd EvaluatePrequentialRegression -l (rules.functions.FadingTargetMean) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/airlines/rules.functions.FadingTargetMean
# Running cmd EvaluatePrequentialRegression -l (functions.AdaGrad) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/airlines/functions.AdaGrad
# Running cmd EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/airlines/meta.AdaptiveRandomForestRegressor
# Running cmd EvaluatePrequentialRegression -l (meta.AdaptiveRandomForestRegressor -m 80) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/airlines/meta.AdaptiveRandomForestRegressor-m80
# Running cmd EvaluatePrequentialRegression -l (rules.AMRulesRegressor) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/airlines/rules.AMRulesRegressor
# Running cmd EvaluatePrequentialRegression -l (rules.functions.Perceptron) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/airlines/rules.functions.Perceptron
# Running cmd EvaluatePrequentialRegression -l (trees.ARFFIMTDD) -s (ArffFileStream -f C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\airlines.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/airlines/trees.ARFFIMTDD

# %%
cmd = 'EvaluatePrequentialRegression -l (rules.functions.TargetMean) -s (ArffFileStream -f C:\\Users\\kosma\\Desktop\\MAGISTER\\FeatExtream\\data\\airlines.arff ) -i 32000 -f 1000 -q 1000 -d runs/tuning/airlines/rules.functions.TargetMean'

run_command(cmd,f'test_airlines')

# %%
file =  r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\wisdm.arff'
task = 'EvaluatePrequential'
learner = 'BufferLearner'

relevance_learner = '(meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'
buffer_learner = f'(meta.AdaptiveRandomForest -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'
stream = f'(ArffFileStream -f {file})'


w = 200
i = 5400
f = 200
q = 200
def generate_command(n, extractor , cluster_num, cluster_type='clustree', buffer_type = 'random', r = 1, target_dir = ''):
    pathlib.Path(f'runs/tuning/{target_dir}').mkdir(parents=True, exist_ok=True)
    
    target_file = f'runs/tuning/{target_dir}wisdm_{extractor}_{n}_{cluster_num}_{cluster_type}_{buffer_type}_{int(r*100)}.csv'
    start_cmd = f'{task} -l ({learner} -l {buffer_learner} -n {n} -m {relevance_learner}'
    end_cmd = f') -s {stream} -e (WindowClassificationPerformanceEvaluator -w {w}) -i {i} -f {f} -q {q} -d {target_file}'
    cmd = f'{start_cmd} -c {extractor} -r {r} -b {buffer_type} -p -1 -q {cluster_type} -x {cluster_num}{end_cmd}'
    cmd = cmd.replace("\\","/")
    return cmd

# %%
generate_command(10, 'cluster', 8, 'clustree', target_dir = 'wisdm/buffer/')
# Out:
# 'EvaluatePrequential -l (BufferLearner -l (meta.AdaptiveRandomForest -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -n 10 -m (meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01)) -c cluster -r 1 -b random -p -1 -q clustree -x 8) -s (ArffFileStream -f C:/Users/kosma/Desktop/MAGISTER/FeatExtream/data/wisdm.arff) -e (WindowClassificationPerformanceEvaluator -w 200) -i 5400 -f 200 -q 200 -d runs/tuning/wisdm/buffer/wisdm_cluster_10_8_clustree_random_100.csv'

# %%
max_together = 10
for n in [1,5,10,25,50,100]:
    cmd = generate_command(n, 'cluster', 8, 'clustree', target_dir = 'wisdm/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'wisdm_cluster_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 1
# Running with n = 5
# Running with n = 10
# Running with n = 25
# Running with n = 50
# Running with n = 100

# %%
max_together = 10
for n in [1,5,10,25,50,100]:
    cmd = generate_command(n, 'cep', 8, 'clustree', target_dir = 'wisdm/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'wisdm_cep_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 1
# Running with n = 5
# Running with n = 10
# Running with n = 25
# Running with n = 50
# Running with n = 100

# %%
max_together = 10
for c in [3,4,6]:
    cmd = generate_command(1, 'cep', c, 'clustree', target_dir = 'wisdm/buffer/')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'wisdm_cep_c{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
for c in [3,4,6]:
    cmd = generate_command(1, 'cep', c, 'clustream', target_dir = 'wisdm/buffer/')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'wisdm_cep_c{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 2
# Running with c = 3
# Running with c = 4
# Running with c = 6

# %%
run_command(cmd,f'tss_{1}')

# %%
max_together = 10
for c in [4,6]:
    cmd = generate_command(1, 'cluster', c, 'clustree', target_dir = 'wisdm/buffer/')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'wisdm_cluster_c{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
for c in [4,6]:
    cmd = generate_command(1, 'cluster', c, 'clustream', target_dir = 'wisdm/buffer/')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'wisdm_cluster_c2{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 4
# Running with c = 6
# Running with c = 4
# Running with c = 6

# %%
max_together = 10
for c in [4,6]:
    cmd = generate_command(1, 'featureExtraction', c, 'clustree', target_dir = 'wisdm/buffer/')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'wisdm_featureExtraction_c{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
for c in [4,6]:
    cmd = generate_command(1, 'featureExtraction', c, 'clustream', target_dir = 'wisdm/buffer/')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'wisdm_featureExtraction_c2{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with c = 4
# Running with c = 6
# Running with c = 4
# Running with c = 6

# %%
for r in rs:
    cmd = generate_command(1, 'featureExtraction', c, 'clustree', buffer_type='relevance', r=r, target_dir = 'wisdm/buffer/')

    print(f"Running with r = {r}")
    out = run_command(cmd,f'featureExtractionp_r2{r}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with r = 0.1
# Running with r = 0.25
# Running with r = 0.5

# %%
for r in rs:
    cmd = generate_command(1, 'featureExtraction', c, 'clustree', buffer_type='random', r=r, target_dir = 'wisdm/buffer/')

    print(f"Running with r = {r}")
    out = run_command(cmd,f'featureExtractionp_r{r}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with r = 0.1
# Running with r = 0.25
# Running with r = 0.5

# %%
max_together = 10
for r in [0.1,0.25,0.5]:
    cmd = generate_command(1, 'featureExtraction', c, 'clustree', target_dir = 'wisdm/buffer/')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'wisdm_featureExtraction_c{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
for c in [4,6]:
    cmd = generate_command(1, 'featureExtraction', c, 'clustream', target_dir = 'wisdm/buffer/')
    print(f"Running with c = {c}")
    out = run_command(cmd,f'wisdm_featureExtraction_c2{c}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()

# %%
file =  r'C:\Users\kosma\Desktop\MAGISTER\FeatExtream\data\electricity_arff.arff'
task = 'EvaluatePrequential'
learner = 'BufferLearner'

relevance_learner = '(meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'
buffer_learner = f'(meta.AdaptiveRandomForest -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'
stream = f'(ArffFileStream -f {file})'


i = 45000
f = 1000
q = 1000
def generate_command(n, extractor , cluster_num, cluster_type='clustree', buffer_type = 'random', r = 1, target_dir = ''):
    pathlib.Path(f'runs/tuning/{target_dir}').mkdir(parents=True, exist_ok=True)
    
    target_file = f'runs/tuning/{target_dir}wisdm_{extractor}_{n}_{cluster_num}_{cluster_type}_{buffer_type}_{int(r*100)}.csv'
    start_cmd = f'{task} -l ({learner} -l {buffer_learner} -n {n} -m {relevance_learner}'
    end_cmd = f') -s {stream} -i {i} -f {f} -q {q} -d {target_file}'
    cmd = f'{start_cmd} -c {extractor} -r {r} -b {buffer_type} -p -1 -q {cluster_type} -x {cluster_num}{end_cmd}'
    cmd = cmd.replace("\\","/")
    return cmd

# %%
max_together = 10
for n in [1,5,10]:
    cmd = generate_command(n, 'cluster', 8, 'clustree', target_dir = 'electricity/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'wisdm_cluster_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 1
# Running with n = 5
# Running with n = 10

# %%
max_together = 10
for n in [1,3,5,10]:
    cmd = generate_command(n, 'cep', 4, 'clustream', target_dir = 'electricity/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'wisdm_cep_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 1
# Running with n = 3
# Running with n = 5
# Running with n = 10

# %%
max_together = 10
for n in [1,3,5, 10]:
    cmd = generate_command(n, 'featureExtraction', 4, 'clustream', target_dir = 'electricity/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'wisdm_featureExtraction_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 1
# Running with n = 3
# Running with n = 5
# Running with n = 10

# %%
task = 'EvaluatePrequential'
learner = 'BufferLearner'

relevance_learner = '(meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'
buffer_learner = f'lazy.SAMkNN'
stream = f'generators.RandomRBFGenerator'


i = 50000
f = 1000
q = 1000
def generate_command(n, extractor , cluster_num, cluster_type='clustree', buffer_type = 'random', r = 1, target_dir = ''):
    pathlib.Path(f'runs/tuning/{target_dir}').mkdir(parents=True, exist_ok=True)
    
    target_file = f'runs/tuning/{target_dir}wisdm_{extractor}_{n}_{cluster_num}_{cluster_type}_{buffer_type}_{int(r*100)}.csv'
    start_cmd = f'{task} -l ({learner} -l {buffer_learner} -n {n} -m {relevance_learner}'
    end_cmd = f') -s {stream} -i {i} -f {f} -q {q} -d {target_file}'
    cmd = f'{start_cmd} -c {extractor} -r {r} -b {buffer_type} -p -1 -q {cluster_type} -x {cluster_num}{end_cmd}'
    cmd = cmd.replace("\\","/")
    return cmd

# %%
max_together = 10
for n in [10]:
    cmd = generate_command(n, 'featureExtraction', 4, 'clustream', target_dir = 'generated/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'generated_featureExtraction_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 10

# %%
max_together = 10
for n in [10]:
    cmd = generate_command(n, 'cep', 4, 'clustream', target_dir = 'generated/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'generated_cep_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 10

# %%
max_together = 10
for n in [10]:
    cmd = generate_command(n, 'cluster', 6, 'clustree', target_dir = 'generated/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'generated_cluster_n{n}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 10

# %%
task = 'EvaluatePrequential'
learner = 'BufferLearner'

relevance_learner = '(meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'
buffer_learner = f'meta.OzaBagAdwin'
stream = f'generators.HyperplaneGenerator'


i = 50000
f = 1000
q = 1000
def generate_command(n, extractor , cluster_num, cluster_type='clustree', buffer_type = 'random', r = 1, target_dir = ''):
    pathlib.Path(f'runs/tuning/{target_dir}').mkdir(parents=True, exist_ok=True)
    
    target_file = f'runs/tuning/{target_dir}hyperplane_{extractor}_{n}_{cluster_num}_{cluster_type}_{buffer_type}_{int(r*100)}.csv'
    start_cmd = f'{task} -l ({learner} -l {buffer_learner} -n {n} -m {relevance_learner}'
    end_cmd = f') -s {stream} -i {i} -f {f} -q {q} -d {target_file}'
    cmd = f'{start_cmd} -c {extractor} -r {r} -b {buffer_type} -p -1 -q {cluster_type} -x {cluster_num}{end_cmd}'
    cmd = cmd.replace("\\","/")
    return cmd

# %%
max_together = 10
for t in ['cluster', 'cep', 'featureExtraction']:
    cmd = generate_command(10, t, 6, 'clustree', target_dir = 'generated/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'generated_{t}_n{10}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 10
# Running with n = 10
# Running with n = 10

# %%
task = 'EvaluatePrequential'
learner = 'BufferLearner'

relevance_learner = '(meta.AdaptiveRandomForestRegressor -x (ADWINChangeDetector -a 0.001) -p (ADWINChangeDetector -a 0.01))'
buffer_learner = f'meta.OzaBagAdwin'
stream = f'generators.LEDGenerator'


i = 50000
f = 1000
q = 1000
def generate_command(n, extractor , cluster_num, cluster_type='clustree', buffer_type = 'random', r = 1, target_dir = ''):
    pathlib.Path(f'runs/tuning/{target_dir}').mkdir(parents=True, exist_ok=True)
    
    target_file = f'runs/tuning/{target_dir}led_{extractor}_{n}_{cluster_num}_{cluster_type}_{buffer_type}_{int(r*100)}.csv'
    start_cmd = f'{task} -l ({learner} -l {buffer_learner} -n {n} -m {relevance_learner}'
    end_cmd = f') -s {stream} -i {i} -f {f} -q {q} -d {target_file}'
    cmd = f'{start_cmd} -c {extractor} -r {r} -b {buffer_type} -p -1 -q {cluster_type} -x {cluster_num}{end_cmd}'
    cmd = cmd.replace("\\","/")
    return cmd

# %%
max_together = 10
for t in ['cluster', 'cep', 'featureExtraction']:
    cmd = generate_command(10, t, 6, 'clustree', target_dir = 'generated/buffer/')
    print(f"Running with n = {n}")
    out = run_command(cmd,f'led_{t}_n{10}')
    outs.append(out)

    if len(outs) >= max_together:
        outs[len(outs) - max_together].communicate()
# Out:
# Running with n = 100
# Running with n = 100
# Running with n = 100
